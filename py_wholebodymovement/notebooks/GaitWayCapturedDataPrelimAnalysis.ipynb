# %% [markdown]
# # Data Analysis for GaitWay Priliminary Data Collection Phase
#
# In this notebook, we conduct exploratory data analysis to investigate various perspectives we can take to look at the data collected during the priliminary data collection using the GaitWay setup.

# %%
import sys
if '/Users/adelardalan/Work/QianLab/autism/py_wholebodymovement/' not in sys.path:
    sys.path.append('/Users/adelardalan/Work/QianLab/autism/py_wholebodymovement/')

import numpy as np
from scipy import interpolate
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pywt

import py_wholebodymovement as wbm

# %% [markdown]
# First, we load the data (ported and preprocessed from the MySQL database table `gaitway_db.captureddata`) from a zip file into the pandas dataframe `captureddata_df`'

# %%
# %%time

captureddata_df = pd.read_csv('../data/captureddata_1.zip', compression='infer')

user_ids    = captureddata_df.UserID.unique()
movements   = captureddata_df.MovementName.unique()
joint_names = wbm.predefined_schemas._JOINT_NAMES_3
# Out:
# CPU times: user 19 s, sys: 1.18 s, total: 20.2 s
# Wall time: 20.2 s

# %% [markdown]
# The loaded dataset contains {{ captureddata_df.shape[0] }} rows each corresponding to a frame. There are {{ len(user_ids) }} participants (also referred to as users) in this dataset performing the following movements during various sessions:
#
# <b>{{ '<br />'.join(sorted(list(movements))) }}</b>
#
# In this notebook, we will only analyze the data for participants `PFLXXX` (dropping some of them too; see below).
#
# The dataset has {{ captureddata_df.shape[1] }} columns, consisting of participant ID, session number, movement name, time stamp, and $(x,y,z)$ coordinates of the {{ len(joint_names) }} points of interest (POIs) on the participants' bodies at each frame performing the moves:
#
# <b>{{ "<br />".join(joint_names) }}</b>

# %% [markdown]
# Here are the first few rows of the dataset:
#
# {{ display(captureddata_df.head()) }}

# %% [markdown]
# Here is a sample frame projected on the 2D $xy$ plane:

# %%
user_id        = 'PFL007'
session_number = 1
movement_name  = 'Idle'
frame_no       = 200

fig = plt.figure(figsize=(6,12))
row = captureddata_df[(captureddata_df.UserID == user_id) & 
                      (captureddata_df.SessionNumber == session_number) &
                      (captureddata_df.MovementName == movement_name)
                     ].iloc[frame_no,:]
xx = row[[cnm for cnm in captureddata_df.columns if '_x' in cnm]]
yy = row[[cnm for cnm in captureddata_df.columns if '_y' in cnm]]
plt.scatter(xx, yy,)
plt.xlim(min(xx)-.1, max(xx)+.1)
plt.ylim(min(yy)-.1, max(yy)+.1)
plt.tick_params(axis='x',which='both',bottom=False,top=False,labelbottom=False)
plt.tick_params(axis='y',which='both',left=False,right=False,labelleft=False)
plt.axis('equal')
plt.show()

# %% [markdown]
# Next, we load the participants' demographic data:

# %%
participant_demographics = pd.read_csv("../data/BOT_dataset_latest_DH_20200428.csv", index_col='Participant_ID')
participant_demographics
# Out:
#                 AGE  GENDER  HEIGHT  WEIGHT  BOT_grossraw_pre  \
# Participant_ID
# PFL001           13       1   177.0    64.2                42
# PFL002           14       1   156.5    51.9                50
# PFL003           17       1   165.0    73.7                43
# PFL004           17       1   191.0    95.6                43
# PFL005           14       1   151.0    35.2                45
# PFL006           10       1    72.8   164.5                29
# PFL007           16       1   153.0    49.5                42
# PFL008           17       2   179.0    89.0                46
# PFL010           11       1   175.0    67.0                47
# PFL012           15       1   153.0    67.6                34
#
#                 BOT_totalraw_pre  BOT_grossraw_post  BOT_totalraw_post  \
# Participant_ID
# PFL001                        69                 45                 71
# PFL002                        75                 50                 76
# PFL003                        70                 43                 68
# PFL004                        64                 40                 66
# PFL005                        65                 40                 67
# PFL006                        55                 35                 61
# PFL007                        69                 47                 73
# PFL008                        72                 47                 73
# PFL010                        74                 46                 73
# PFL012                        56                 33                 53
#
#                 Flanker_rawpre  Flanker_rawpost  ...  DSM_hyper  DSM_cond  \
# Participant_ID                                   ...
# PFL001                    20.0               19  ...         23         1
# PFL002                     NaN               19  ...         22         1
# PFL003                    19.0               20  ...          6         1
# PFL004                    20.0               20  ...          9         2
# PFL005                    20.0               20  ...          1         1
# PFL006                    20.0               20  ...         24         3
# PFL007                    20.0               20  ...          0         0
# PFL008                    20.0               20  ...         14         4
# PFL010                    20.0               20  ...          8         0
# PFL012                    20.0               19  ...         18         0
#
#                 DSM_opp  Conners_Global_interp  Conners_inattent_interp  \
# Participant_ID
# PFL001                3                      5                        5
# PFL002                9                      5                        2
# PFL003                6                      4                        2
# PFL004               11                      5                        5
# PFL005                1                      2                        4
# PFL006               10                      5                        5
# PFL007                0                      2                        2
# PFL008                6                      4                        3
# PFL010                1                      2                        5
# PFL012                2                      4                        5
#
#                 Conners_hyperact_interp  Conners_learn_prob_interp  \
# Participant_ID
# PFL001                                5                          3
# PFL002                                5                          2
# PFL003                                4                          2
# PFL004                                5                          5
# PFL005                                4                          5
# PFL006                                5                          4
# PFL007                                2                          2
# PFL008                                5                          3
# PFL010                                3                          5
# PFL012                                2                          2
#
#                 Conners_exec_prob_interp  Conners_defiance_interp  \
# Participant_ID
# PFL001                                 5                        3
# PFL002                                 2                        2
# PFL003                                 2                        2
# PFL004                                 4                        2
# PFL005                                 2                        2
# PFL006                                 4                        5
# PFL007                                 2                        2
# PFL008                                 2                        4
# PFL010                                 5                        2
# PFL012                                 2                        2
#
#                 Conners_peer_rel_interp
# Participant_ID
# PFL001                                5
# PFL002                                5
# PFL003                                3
# PFL004                                5
# PFL005                                5
# PFL006                                5
# PFL007                                4
# PFL008                                5
# PFL010                                2
# PFL012                                5
#
# [10 rows x 82 columns]

# %% [markdown]
# We note that the participants are not gender balanced and should consider this in all of our analysis and possible conclusions.

# %% [markdown]
# ## Breaking Down the Sessions to Individual Moves
#
# Each session consists of a participant performing a sequence of moves and in this analysis, we wish to look at the data at the single _move_ level; that is, we want to look at various repetitions of a movement (e.g. jumping jacks) during a session separately. The following scrips creates a copy `captureddata_df_augmented` of the original dataset `captureddata_df` and change the movement names to unique move names of the format `<MOVE>@<FRAME>` where `MOVE` is one of the {{ len(movements) }} possible movements and `FRAME` is the ending frame of the corresponding move. For now we focus on the first few sessions only, determined by the value of `max_sessions` variable.

# %%
# %%time

max_sessions   = 6

unique_user_ids        = [gg for gg in captureddata_df.UserID.unique() if 'PFL' in gg]
unique_user_ids        = sorted(unique_user_ids)
unique_movement_names  = captureddata_df.MovementName.unique()
unique_session_numbers = captureddata_df.SessionNumber.unique()

captureddata_df_augmented = pd.DataFrame(columns=captureddata_df.columns)

for user_id_idx in range(len(unique_user_ids)):
    user_id = unique_user_ids[user_id_idx]
    print("User %s"%user_id)
    
    user_movement_session_numbers = sorted(captureddata_df[(captureddata_df.UserID==user_id) #& 
                                                   ].SessionNumber.unique())[:max_sessions]

    user_movement_session_numbers.sort()
    for session_number_inx in range(len(user_movement_session_numbers)):
        session_number = user_movement_session_numbers[session_number_inx]
        print("\tSessions %d"%session_number)
        
        session_data = captureddata_df[(captureddata_df.UserID == user_id) & 
                              (captureddata_df.SessionNumber == session_number) #&
                             ]
        if session_data.shape[0] == 0:
            continue

        captureddata_df_augmented = pd.concat([captureddata_df_augmented, session_data], axis=0)
        
        latest_movement_inx       = np.inf
        latest_movement_start_inx = session_data.index[0]
        latest_movement           = session_data.loc[latest_movement_start_inx, :].MovementName
        
        has_data = True
        
        while has_data:
            session_data_slice            = session_data.loc[latest_movement_start_inx:, :]
            
            latest_movement_start_inx     = session_data_slice.MovementName.ne(latest_movement).idxmax()
            
            if latest_movement_start_inx == session_data_slice.index[0]:
                has_data = False
                latest_movement_start_inx = session_data_slice.index[-1]

            captureddata_df_augmented.loc[session_data_slice.index[0]:latest_movement_start_inx, 'MovementName'
                                          ] = latest_movement+'@%d'%latest_movement_start_inx

            latest_movement               = session_data.loc[latest_movement_start_inx, :].MovementName

            print("\t\tMove %s at %d"%(latest_movement, latest_movement_start_inx))
# Out:
# User PFL001
# 	Sessions 1
# 		Move Walk at 1549440
# 		Move OLB at 1549500
# 		Move TheShoot at 1549620
# 		Move Walk at 1549680
# 		Move Idle at 1549740
# 		Move OLB at 1550220
# 		Move Idle at 1550400
# 		Move OLB at 1550460
# 		Move JumpBack at 1550820
# 		Move OLB at 1550880
# 		Move Walk at 1550940
# 		Move Idle at 1551000
# 		Move JumpingJack at 1551120
# 		Move Idle at 1551180
# 		Move JumpingJack at 1551420
# 		Move TouchingNose at 1551480
# 		Move JumpingJack at 1551660
# 		Move Idle at 1551960
# 		Move JumpRight at 1552020
# 		Move Idle at 1552080
# 		Move OLB at 1552440
# 		Move Idle at 1552500
# 		Move OLB at 1552920
# 		Move Idle at 1553400
# 		Move OLB at 1553460
# 		Move Idle at 1553820
# 		Move JumpForward at 1554180
# 		Move Idle at 1554240
# 		Move JumpForward at 1554300
# 		Move Walk at 1554360
# 		Move TheShoot at 1554480
# 		Move Walk at 1554540
# 		Move Idle at 1554600
# 		Move OLB at 1554660
# 		Move Idle at 1554840
# 		Move JumpBack at 1555860
# 		Move Idle at 1555920
# 		Move Walk at 1555980
# 		Move OLB at 1556040
# 		Move TheShoot at 1556100
# 		Move JumpForward at 1556160
# 		Move JumpRight at 1556220
# 		Move OLB at 1556280
# 		Move TheShoot at 1556340
# 		Move Idle at 1556400
# 		Move Idle at 1576439
# 	Sessions 2
# 		Move JumpingJack at 1745040
# 		Move Idle at 1745100
# 		Move Idle at 1751039
# 	Sessions 3
# 		Move Idle at 1913459
# 	Sessions 4
# 		Move TheShoot at 2324160
# 		Move Walk at 2324220
# 		Move Idle at 2324280
# 		Move OLB at 2324340
# 		Move TheShoot at 2324400
# 		Move TouchingNose at 2324460
# 		Move OLB at 2324640
# 		Move Idle at 2324700
# 		Move TheShoot at 2324760
# 		Move Idle at 2324820
# 		Move TheShoot at 2324940
# 		Move TouchingNose at 2325000
# 		Move Idle at 2325180
# 		Move TouchingNose at 2325540
# 		Move Idle at 2325720
# 		Move JumpingJack at 2325840
# 		Move TouchingNose at 2325900
# 		Move TheShoot at 2326020
# 		Move Idle at 2326080
# 		Move TheShoot at 2326200
# 		Move TouchingNose at 2326260
# 		Move JumpingJack at 2326320
# 		Move TouchingNose at 2326380
# 		Move Idle at 2326500
# 		Move OLB at 2326980
# 		Move TheShoot at 2327040
# 		Move Walk at 2327100
# 		Move OLB at 2327160
# 		Move Idle at 2327220
# 		Move Walk at 2327280
# 		Move JumpLeft at 2327340
# 		Move Idle at 2327400
# 		Move TheShoot at 2327520
# 		Move Idle at 2327700
# 		Move TheShoot at 2327760
# 		Move Idle at 2327880
# 		Move TheShoot at 2327940
# 		Move OLB at 2328060
# 		Move Idle at 2328180
# 		Move TheShoot at 2328240
# 		Move OLB at 2328300
# 		Move TheShoot at 2328360
# 		Move Idle at 2328420
# 		Move OLB at 2328660
# 		Move Idle at 2328780
# 		Move TheShoot at 2328840
# 		Move Idle at 2328900
# 		Move TheShoot at 2329020
# 		Move TouchingNose at 2329140
# 		Move TheShoot at 2329200
# 		Move OLB at 2329320
# 		Move TheShoot at 2329380
# 		Move OLB at 2329440
# 		Move TheShoot at 2329500
# 		Move OLB at 2329560
# 		Move Idle at 2329800
# 		Move OLB at 2329980
# 		Move TheShoot at 2330040
# 		Move Idle at 2330160
# 		Move OLB at 2330400
# 		Move TheShoot at 2330580
# 		Move Idle at 2330640
# 		Move OLB at 2330700
# 		Move TheShoot at 2330760
# 		Move OLB at 2330880
# 		Move Idle at 2330940
# 		Move Walk at 2331000
# 		Move OLB at 2331060
# 		Move TheShoot at 2331360
# 		Move Idle at 2331420
# 		Move TheShoot at 2331480
# 		Move Idle at 2331600
# 		Move OLB at 2331720
# 		Move Idle at 2332140
# 		Move OLB at 2332260
# 		Move TheShoot at 2332320
# 		Move Idle at 2332440
# 		Move OLB at 2332500
# 		Move TheShoot at 2332560
# 		Move OLB at 2332680
# 		Move TheShoot at 2333220
# 		Move Walk at 2333280
# 		Move JumpRight at 2333340
# 		Move Idle at 2333400
# 		Move OLB at 2333520
# 		Move Idle at 2333640
# 		Move OLB at 2333700
# 		Move TheShoot at 2333760
# 		Move Walk at 2333880
# 		Move JumpForward at 2333940
# 		Move OLB at 2334000
# 		Move Idle at 2334060
# 		Move TheShoot at 2334120
# 		Move Idle at 2334180
# 		Move TheShoot at 2334240
# 		Move OLB at 2334300
# 		Move TheShoot at 2334480
# 		Move Idle at 2334540
# 		Move OLB at 2334600
# 		Move TheShoot at 2334840
# 		Move JumpBack at 2334900
# 		Move OLB at 2334960
# 		Move Walk at 2335020
# 		Move TheShoot at 2335080
# 		Move Idle at 2335140
# 		Move OLB at 2335260
# 		Move Idle at 2335380
# 		Move JumpRight at 2335500
# 		Move Idle at 2335560
# 		Move TheShoot at 2335740
# 		Move JumpBack at 2335800
# 		Move JumpRight at 2335860
# 		Move TheShoot at 2335920
# 		Move Idle at 2335980
# 		Move Walk at 2337000
# 		Move OLB at 2337120
# 		Move Idle at 2337360
# 		Move OLB at 2337720
# 		Move Idle at 2337780
# 		Move Idle at 2352719
# User PFL002
# 	Sessions 1
# 		Move Walk at 3780
# 		Move Idle at 3840
# 		Move OLB at 3900
# 		Move Walk at 3960
# 		Move Idle at 4020
# 		Move Walk at 4200
# 		Move OLB at 4260
# 		Move Idle at 4380
# 		Move TheShoot at 4680
# 		Move Idle at 4740
# 		Move OLB at 4800
# 		Move Idle at 4860
# 		Move JumpForward at 4980
# 		Move Idle at 5040
# 		Move TheShoot at 5220
# 		Move OLB at 5280
# 		Move Idle at 5340
# 		Move TheShoot at 5460
# 		Move OLB at 5820
# 		Move TheShoot at 5880
# 		Move JumpingJack at 6000
# 		Move OLB at 6060
# 		Move Idle at 6120
# 		Move JumpingJack at 6360
# 		Move TheShoot at 6780
# 		Move Idle at 6840
# 		Move OLB at 6900
# 		Move Idle at 6960
# 		Move OLB at 7260
# 		Move TheShoot at 7380
# 		Move Idle at 7500
# 		Move JumpForward at 7620
# 		Move Idle at 7680
# 		Move Walk at 7800
# 		Move TheShoot at 7860
# 		Move Idle at 7920
# 		Move OLB at 7980
# 		Move TheShoot at 8040
# 		Move OLB at 8100
# 		Move Idle at 8220
# 		Move OLB at 8280
# 		Move Idle at 8820
# 		Move JumpForward at 9240
# 		Move OLB at 9300
# 		Move Idle at 9420
# 		Move OLB at 9480
# 		Move Idle at 9720
# 		Move OLB at 9780
# 		Move Idle at 9900
# 		Move JumpRight at 10140
# 		Move Idle at 10200
# 		Move OLB at 10320
# 		Move Idle at 10380
# 		Move OLB at 10500
# 		Move JumpRight at 10560
# 		Move TheShoot at 10620
# 		Move JumpLeft at 10800
# 		Move Idle at 10860
# 		Move TheShoot at 10920
# 		Move OLB at 10980
# 		Move TheShoot at 11040
# 		Move OLB at 11160
# 		Move Idle at 11220
# 		Move OLB at 27420
# 		Move Idle at 27480
# 		Move OLB at 27540
# 		Move Idle at 27780
# 		Move OLB at 27840
# 		Move Idle at 27900
# 		Move OLB at 28020
# 		Move Idle at 28080
# 		Move TouchingNose at 28260
# 		Move TheShoot at 28440
# 		Move OLB at 28560
# 		Move Idle at 28620
# 		Move JumpingJack at 28680
# 		Move Idle at 28740
# 		Move TouchingNose at 28800
# 		Move Idle at 28920
# 		Move OLB at 29040
# 		Move TheShoot at 29100
# 		Move Idle at 29160
# 		Move JumpingJack at 29280
# 		Move TouchingNose at 29340
# 		Move Idle at 29460
# 		Move OLB at 29520
# 		Move Idle at 29700
# 		Move OLB at 29820
# 		Move JumpingJack at 29880
# 		Move TheShoot at 29940
# 		Move JumpingJack at 30000
# 		Move Idle at 30180
# 		Move TheShoot at 30240
# 		Move OLB at 30360
# 		Move TheShoot at 30540
# 		Move Idle at 30600
# 		Move OLB at 30900
# 		Move JumpingJack at 30960
# 		Move OLB at 31020
# 		Move Idle at 31080
# 		Move OLB at 31260
# 		Move JumpingJack at 31500
# 		Move Idle at 31560
# 		Move OLB at 31620
# 		Move TheShoot at 31680
# 		Move Idle at 31800
# 		Move OLB at 31980
# 		Move Idle at 32040
# 		Move TheShoot at 32100
# 		Move OLB at 32220
# 		Move Idle at 32340
# 		Move OLB at 32400
# 		Move TheShoot at 32520
# 		Move Idle at 32640
# 		Move TheShoot at 32760
# 		Move Idle at 32880
# 		Move JumpingJack at 33180
# 		Move TheShoot at 33360
# 		Move OLB at 33600
# 		Move Idle at 33720
# 		Move JumpingJack at 33780
# 		Move TheShoot at 34020
# 		Move Idle at 34080
# 		Move OLB at 34140
# 		Move TheShoot at 34200
# 		Move OLB at 34380
# 		Move Idle at 34440
# 		Move JumpingJack at 34560
# 		Move Idle at 34620
# 		Move TheShoot at 34800
# 		Move Idle at 34860
# 		Move JumpingJack at 34920
# 		Move Idle at 34980
# 		Move JumpingJack at 35220
# 		Move Idle at 35280
# 		Move OLB at 35340
# 		Move Idle at 35400
# 		Move OLB at 35460
# 		Move Idle at 35520
# 		Move JumpRight at 35580
# 		Move Idle at 35640
# 		Move TheShoot at 35760
# 		Move Idle at 35820
# 		Move JumpingJack at 35880
# 		Move TouchingNose at 35940
# 		Move OLB at 36060
# 		Move TheShoot at 36120
# 		Move JumpingJack at 36180
# 		Move TheShoot at 36540
# 		Move JumpForward at 36720
# 		Move Walk at 36780
# 		Move OLB at 36840
# 		Move JumpRight at 36960
# 		Move TheShoot at 37020
# 		Move OLB at 37080
# 		Move TheShoot at 37200
# 		Move Walk at 37260
# 		Move Idle at 37320
# 		Move OLB at 37380
# 		Move Idle at 37440
# 		Move TheShoot at 37560
# 		Move JumpingJack at 37620
# 		Move Idle at 37680
# 		Move JumpForward at 37800
# 		Move Idle at 37860
# 		Move OLB at 37920
# 		Move TheShoot at 38040
# 		Move OLB at 38100
# 		Move TheShoot at 38160
# 		Move OLB at 38460
# 		Move Walk at 38520
# 		Move OLB at 38580
# 		Move Idle at 38700
# 		Move JumpLeft at 38760
# 		Move TheShoot at 38820
# 		Move JumpingJack at 38940
# 		Move Idle at 39000
# 		Move TheShoot at 39060
# 		Move JumpingJack at 39300
# 		Move TheShoot at 39360
# 		Move OLB at 39480
# 		Move Idle at 39540
# 		Move TheShoot at 39600
# 		Move Idle at 39660
# 		Move TheShoot at 39720
# 		Move Idle at 39840
# 		Move JumpingJack at 39900
# 		Move TheShoot at 39960
# 		Move JumpingJack at 40020
# 		Move TheShoot at 40200
# 		Move OLB at 40260
# 		Move Idle at 40320
# 		Move OLB at 40440
# 		Move Walk at 40500
# 		Move OLB at 40620
# 		Move TheShoot at 40740
# 		Move Walk at 40800
# 		Move Idle at 40860
# 		Move TheShoot at 41100
# 		Move JumpingJack at 41220
# 		Move OLB at 41340
# 		Move TheShoot at 41400
# 		Move Idle at 41460
# 		Move Walk at 41520
# 		Move TheShoot at 41640
# 		Move Idle at 41820
# 		Move TheShoot at 41880
# 		Move OLB at 42000
# 		Move OLB at 42059
# 	Sessions 3
# 		Move Idle at 145319
# 	Sessions 4
# 		Move Idle at 303179
# 	Sessions 5
# 		Move Idle at 546419
# 	Sessions 6
# 		Move OLB at 944940
# 		Move TheShoot at 945000
# 		Move JumpingJack at 945120
# 		Move TheShoot at 945180
# 		Move JumpingJack at 945240
# 		Move Walk at 945360
# 		Move OLB at 945420
# 		Move Idle at 945480
# 		Move OLB at 945600
# 		Move Idle at 945660
# 		Move OLB at 945780
# 		Move TheShoot at 945840
# 		Move JumpForward at 945900
# 		Move TheShoot at 945960
# 		Move Idle at 946020
# 		Move OLB at 946080
# 		Move Idle at 946200
# 		Move OLB at 946260
# 		Move Idle at 946380
# 		Move OLB at 946440
# 		Move Idle at 946560
# 		Move OLB at 946620
# 		Move TheShoot at 946740
# 		Move Idle at 946800
# 		Move OLB at 946860
# 		Move TheShoot at 946920
# 		Move JumpingJack at 947040
# 		Move TheShoot at 947100
# 		Move JumpingJack at 947160
# 		Move OLB at 947280
# 		Move Idle at 947340
# 		Move OLB at 947400
# 		Move JumpingJack at 947460
# 		Move JumpRight at 947580
# 		Move TheShoot at 947640
# 		Move Idle at 947700
# 		Move OLB at 947760
# 		Move Idle at 947820
# 		Move TheShoot at 947880
# 		Move Idle at 947940
# 		Move OLB at 948000
# 		Move Idle at 948060
# 		Move OLB at 948180
# 		Move Idle at 948240
# 		Move OLB at 948300
# 		Move TheShoot at 948480
# 		Move OLB at 948540
# 		Move TheShoot at 948660
# 		Move Idle at 948720
# 		Move TheShoot at 948840
# 		Move TouchingNose at 949080
# 		Move Idle at 949260
# 		Move OLB at 949320
# 		Move TheShoot at 949440
# 		Move Idle at 949500
# 		Move OLB at 949560
# 		Move TheShoot at 949620
# 		Move Idle at 949680
# 		Move OLB at 949740
# 		Move Idle at 949860
# 		Move OLB at 949920
# 		Move Idle at 949980
# 		Move TheShoot at 950040
# 		Move Idle at 950100
# 		Move TheShoot at 950220
# 		Move JumpingJack at 950280
# 		Move TheShoot at 950340
# 		Move JumpingJack at 950400
# 		Move TheShoot at 950520
# 		Move OLB at 950580
# 		Move Walk at 950700
# 		Move Idle at 950760
# 		Move TheShoot at 950880
# 		Move OLB at 951840
# 		Move Idle at 951900
# 		Move OLB at 951960
# 		Move TheShoot at 952020
# 		Move OLB at 952080
# 		Move Idle at 952140
# 		Move OLB at 952260
# 		Move TheShoot at 952320
# 		Move OLB at 952380
# 		Move Idle at 952440
# 		Move OLB at 952500
# 		Move Idle at 952560
# 		Move Idle at 960059
# 	Sessions 7
# 		Move TheShoot at 1233120
# 		Move Walk at 1233180
# 		Move TheShoot at 1233240
# 		Move Idle at 1233300
# 		Move JumpingJack at 1233540
# 		Move OLB at 1233600
# 		Move JumpRight at 1233780
# 		Move Idle at 1233840
# 		Move TheShoot at 1233960
# 		Move Idle at 1234020
# 		Move OLB at 1234080
# 		Move Idle at 1234200
# 		Move OLB at 1234260
# 		Move TheShoot at 1234380
# 		Move JumpingJack at 1234440
# 		Move TheShoot at 1234560
# 		Move OLB at 1234740
# 		Move TheShoot at 1234800
# 		Move JumpForward at 1234860
# 		Move TheShoot at 1234920
# 		Move JumpForward at 1234980
# 		Move TheShoot at 1235040
# 		Move Walk at 1235100
# 		Move JumpForward at 1235160
# 		Move OLB at 1235340
# 		Move TheShoot at 1235400
# 		Move OLB at 1235460
# 		Move Walk at 1235580
# 		Move TheShoot at 1235760
# 		Move JumpForward at 1235820
# 		Move JumpRight at 1235880
# 		Move JumpLeft at 1235940
# 		Move Walk at 1236000
# 		Move JumpForward at 1236060
# 		Move JumpLeft at 1236120
# 		Move Walk at 1236180
# 		Move JumpForward at 1236240
# 		Move Walk at 1236300
# 		Move JumpLeft at 1236360
# 		Move JumpForward at 1236420
# 		Move Walk at 1236540
# 		Move TheShoot at 1236600
# 		Move Walk at 1236660
# 		Move OLB at 1236720
# 		Move Walk at 1236780
# 		Move TheShoot at 1236840
# 		Move JumpBack at 1236960
# 		Move JumpForward at 1237020
# 		Move Walk at 1237080
# 		Move JumpBack at 1237140
# 		Move Walk at 1237200
# 		Move TheShoot at 1237320
# 		Move Walk at 1237380
# 		Move TheShoot at 1237440
# 		Move Walk at 1237500
# 		Move JumpForward at 1237560
# 		Move TheShoot at 1237620
# 		Move JumpForward at 1237680
# 		Move JumpLeft at 1237800
# 		Move OLB at 1237860
# 		Move TheShoot at 1237980
# 		Move JumpRight at 1238280
# 		Move Walk at 1238340
# 		Move TheShoot at 1238460
# 		Move JumpForward at 1238520
# 		Move TheShoot at 1238820
# 		Move JumpForward at 1239000
# 		Move TheShoot at 1239060
# 		Move OLB at 1239120
# 		Move Walk at 1239300
# 		Move OLB at 1239360
# 		Move TheShoot at 1239420
# 		Move JumpingJack at 1239540
# 		Move OLB at 1239600
# 		Move TheShoot at 1239660
# 		Move OLB at 1239720
# 		Move TheShoot at 1239780
# 		Move JumpForward at 1239840
# 		Move Walk at 1239900
# 		Move TheShoot at 1239960
# 		Move Walk at 1240080
# 		Move JumpForward at 1240140
# 		Move Walk at 1240200
# 		Move TheShoot at 1240260
# 		Move Walk at 1240320
# 		Move JumpRight at 1240380
# 		Move JumpForward at 1240440
# 		Move Walk at 1240500
# 		Move TheShoot at 1240560
# 		Move JumpForward at 1240680
# 		Move Walk at 1240740
# 		Move TheShoot at 1240800
# 		Move Walk at 1240860
# 		Move Idle at 1240920
# 		Move TheShoot at 1241040
# 		Move OLB at 1241220
# 		Move Idle at 1241460
# 		Move OLB at 1241580
# 		Move TheShoot at 1241640
# 		Move Walk at 1241820
# 		Move TheShoot at 1241880
# 		Move JumpForward at 1241940
# 		Move TheShoot at 1242000
# 		Move JumpLeft at 1242120
# 		Move TheShoot at 1242180
# 		Move JumpForward at 1242240
# 		Move TheShoot at 1242360
# 		Move OLB at 1242480
# 		Move TouchingNose at 1242540
# 		Move JumpForward at 1242600
# 		Move TheShoot at 1242660
# 		Move Idle at 1242720
# 		Move Walk at 1242780
# 		Move OLB at 1242840
# 		Move TheShoot at 1242900
# 		Move Walk at 1243620
# 		Move Idle at 1243680
# 		Move JumpForward at 1243740
# 		Move OLB at 1243800
# 		Move TheShoot at 1243860
# 		Move Walk at 1243920
# 		Move Idle at 1243980
# 		Move OLB at 1244040
# 		Move Idle at 1244100
# 		Move TheShoot at 1244160
# 		Move Idle at 1244220
# 		Move JumpRight at 1244280
# 		Move TheShoot at 1244400
# 		Move Idle at 1244460
# 		Move Walk at 1244520
# 		Move Idle at 1244580
# 		Move JumpingJack at 1244640
# 		Move TheShoot at 1244880
# 		Move Idle at 1244940
# 		Move TheShoot at 1245180
# 		Move Walk at 1245240
# 		Move TheShoot at 1245300
# 		Move Idle at 1245600
# 		Move TheShoot at 1245660
# 		Move Idle at 1245720
# 		Move TouchingNose at 1246680
# 		Move Idle at 1247100
# 		Move TheShoot at 1247220
# 		Move Walk at 1247280
# 		Move TheShoot at 1247340
# 		Move Idle at 1247400
# 		Move OLB at 1247580
# 		Move Idle at 1247640
# 		Move TheShoot at 1247700
# 		Move TouchingNose at 1248000
# 		Move OLB at 1248180
# 		Move TheShoot at 1248360
# 		Move OLB at 1248420
# 		Move JumpForward at 1248480
# 		Move TheShoot at 1248540
# 		Move OLB at 1248720
# 		Move JumpingJack at 1248780
# 		Move TouchingNose at 1248840
# 		Move JumpingJack at 1248960
# 		Move Idle at 1249020
# 		Move TheShoot at 1249080
# 		Move Idle at 1249140
# 		Move TheShoot at 1250400
# 		Move Idle at 1250460
# 		Move TheShoot at 1250520
# 		Move Idle at 1250760
# 		Move TheShoot at 1251840
# 		Move Idle at 1251900
# 		Move TheShoot at 1252680
# 		Move OLB at 1252800
# 		Move JumpBack at 1252860
# 		Move TheShoot at 1252920
# 		Move JumpRight at 1252980
# 		Move Idle at 1253040
# 		Move OLB at 1253100
# 		Move Idle at 1253160
# 		Move JumpingJack at 1253340
# 		Move OLB at 1253520
# 		Move Walk at 1253580
# 		Move TheShoot at 1253640
# 		Move Idle at 1253700
# 		Move TheShoot at 1253760
# 		Move JumpRight at 1253940
# 		Move TouchingNose at 1254000
# 		Move JumpingJack at 1254180
# 		Move Idle at 1254300
# 		Move TheShoot at 1254420
# 		Move OLB at 1254480
# 		Move JumpingJack at 1254540
# 		Move TouchingNose at 1254600
# 		Move Idle at 1254780
# 		Move Walk at 1254840
# 		Move Idle at 1254900
# 		Move OLB at 1255020
# 		Move Idle at 1255200
# 		Move TheShoot at 1255440
# 		Move JumpingJack at 1255500
# 		Move Walk at 1255560
# 		Move JumpLeft at 1255620
# 		Move TheShoot at 1255680
# 		Move JumpLeft at 1255800
# 		Move JumpingJack at 1255920
# 		Move Idle at 1255980
# 		Move JumpingJack at 1256100
# 		Move Idle at 1256160
# 		Move OLB at 1256340
# 		Move TheShoot at 1256400
# 		Move Idle at 1256520
# 		Move TheShoot at 1256880
# 		Move Idle at 1256940
# 		Move JumpForward at 1257240
# 		Move JumpRight at 1257300
# 		Move OLB at 1257360
# 		Move Idle at 1257420
# 		Move JumpingJack at 1257480
# 		Move Walk at 1257540
# 		Move Idle at 1257600
# 		Move TheShoot at 1257660
# 		Move JumpRight at 1257720
# 		Move Idle at 1257780
# 		Move TheShoot at 1257840
# 		Move TouchingNose at 1257900
# 		Move Idle at 1258320
# 		Move OLB at 1258380
# 		Move Idle at 1258440
# 		Move OLB at 1258500
# 		Move TheShoot at 1258560
# 		Move Idle at 1258620
# 		Move OLB at 1258680
# 		Move TheShoot at 1258740
# 		Move JumpForward at 1258920
# 		Move Idle at 1258980
# 		Move TheShoot at 1259220
# 		Move Idle at 1259280
# 		Move OLB at 1259340
# 		Move TheShoot at 1259400
# 		Move TouchingNose at 1259460
# 		Move JumpingJack at 1259640
# 		Move TheShoot at 1259700
# 		Move JumpingJack at 1259760
# 		Move TouchingNose at 1259820
# 		Move TheShoot at 1260000
# 		Move TouchingNose at 1260060
# 		Move TheShoot at 1260240
# 		Move TouchingNose at 1260300
# 		Move OLB at 1260540
# 		Move TheShoot at 1260600
# 		Move OLB at 1260660
# 		Move Idle at 1260720
# 		Move TheShoot at 1260840
# 		Move Idle at 1260900
# 		Move OLB at 1260960
# 		Move Idle at 1261020
# 		Move TouchingNose at 1261080
# 		Move JumpingJack at 1261260
# 		Move Idle at 1261320
# 		Move OLB at 1261380
# 		Move TheShoot at 1261440
# 		Move Idle at 1261500
# 		Move JumpBack at 1261560
# 		Move TheShoot at 1261620
# 		Move Idle at 1261740
# 		Move Walk at 1261800
# 		Move TheShoot at 1261920
# 		Move JumpingJack at 1262040
# 		Move TheShoot at 1262100
# 		Move Idle at 1262160
# 		Move TheShoot at 1262220
# 		Move Idle at 1262280
# 		Move TheShoot at 1262340
# 		Move OLB at 1262460
# 		Move Idle at 1262580
# 		Move TheShoot at 1262640
# 		Move JumpingJack at 1262880
# 		Move TheShoot at 1263000
# 		Move OLB at 1263060
# 		Move TheShoot at 1263120
# 		Move OLB at 1263420
# 		Move TheShoot at 1263540
# 		Move Idle at 1263660
# 		Move Idle at 1263959
# User PFL003
# 	Sessions 1
# 		Move OLB at 1144680
# 		Move Idle at 1144800
# 		Move Walk at 1144860
# 		Move OLB at 1144920
# 		Move Idle at 1145340
# 		Move OLB at 1146060
# 		Move JumpingJack at 1146120
# 		Move TheShoot at 1146240
# 		Move Idle at 1146360
# 		Move OLB at 1146540
# 		Move Idle at 1146600
# 		Move OLB at 1146660
# 		Move Idle at 1146720
# 		Move TheShoot at 1146780
# 		Move Idle at 1146840
# 		Move JumpingJack at 1146960
# 		Move Idle at 1147020
# 		Move OLB at 1147080
# 		Move TheShoot at 1147200
# 		Move OLB at 1147260
# 		Move TheShoot at 1148160
# 		Move Idle at 1148280
# 		Move OLB at 1148340
# 		Move TheShoot at 1148580
# 		Move OLB at 1148640
# 		Move TheShoot at 1148760
# 		Move Idle at 1148820
# 		Move OLB at 1149000
# 		Move TheShoot at 1149120
# 		Move Idle at 1149180
# 		Move OLB at 1149300
# 		Move Idle at 1149360
# 		Move OLB at 1149420
# 		Move Idle at 1149480
# 		Move JumpingJack at 1149600
# 		Move TheShoot at 1149660
# 		Move OLB at 1149960
# 		Move Idle at 1150260
# 		Move Idle at 1150319
# 	Sessions 2
# 		Move Idle at 1153079
# 	Sessions 3
# 		Move Idle at 1161359
# 	Sessions 4
# 		Move OLB at 1513560
# 		Move Walk at 1513800
# 		Move OLB at 1513860
# 		Move Walk at 1513980
# 		Move OLB at 1514040
# 		Move Idle at 1514100
# 		Move OLB at 1514160
# 		Move Idle at 1514220
# 		Move OLB at 1514340
# 		Move TheShoot at 1515360
# 		Move Idle at 1515420
# 		Move OLB at 1515480
# 		Move Idle at 1515660
# 		Move OLB at 1515720
# 		Move TheShoot at 1515840
# 		Move OLB at 1515900
# 		Move Idle at 1515960
# 		Move OLB at 1516080
# 		Move TheShoot at 1516260
# 		Move JumpingJack at 1516320
# 		Move Idle at 1516380
# 		Move OLB at 1516500
# 		Move TheShoot at 1516740
# 		Move JumpingJack at 1516860
# 		Move TheShoot at 1516920
# 		Move JumpingJack at 1517040
# 		Move TheShoot at 1517160
# 		Move OLB at 1517280
# 		Move Idle at 1518060
# 		Move OLB at 1518180
# 		Move Idle at 1518360
# 		Move OLB at 1518420
# 		Move Idle at 1519320
# 		Move OLB at 1519380
# 		Move Idle at 1519440
# 		Move OLB at 1519500
# 		Move Idle at 1519560
# 		Move OLB at 1519620
# 		Move TheShoot at 1519860
# 		Move OLB at 1519920
# 		Move Idle at 1520100
# 		Move OLB at 1520160
# 		Move TheShoot at 1520760
# 		Move OLB at 1520820
# 		Move Idle at 1521180
# 		Move TheShoot at 1521360
# 		Move OLB at 1521480
# 		Move JumpForward at 1521540
# 		Move Idle at 1521600
# 		Move TheShoot at 1521660
# 		Move Idle at 1521780
# 		Move TheShoot at 1529760
# 		Move OLB at 1529820
# 		Move TheShoot at 1530600
# 		Move TouchingNose at 1530720
# 		Move TheShoot at 1530840
# 		Move Idle at 1530900
# 		Move OLB at 1530960
# 		Move TheShoot at 1531680
# 		Move TouchingNose at 1531740
# 		Move TheShoot at 1531860
# 		Move Idle at 1531920
# 		Move OLB at 1531980
# 		Move Idle at 1532040
# 		Move OLB at 1532160
# 		Move Idle at 1532580
# 		Move TheShoot at 1532640
# 		Move OLB at 1532700
# 		Move Idle at 1532760
# 		Move OLB at 1532820
# 		Move Idle at 1532880
# 		Move OLB at 1532940
# 		Move Idle at 1533060
# 		Move OLB at 1533180
# 		Move Idle at 1533300
# 		Move OLB at 1533420
# 		Move TheShoot at 1533480
# 		Move OLB at 1533540
# 		Move Idle at 1533600
# 		Move OLB at 1533660
# 		Move Idle at 1533720
# 		Move OLB at 1533780
# 		Move Idle at 1533900
# 		Move OLB at 1533960
# 		Move Idle at 1534380
# 		Move TheShoot at 1534440
# 		Move Idle at 1534560
# 		Move OLB at 1534680
# 		Move Idle at 1534920
# 		Move OLB at 1535040
# 		Move TheShoot at 1535100
# 		Move OLB at 1535160
# 		Move Idle at 1535460
# 		Move OLB at 1535580
# 		Move Idle at 1535880
# 		Move OLB at 1536000
# 		Move Idle at 1536060
# 		Move OLB at 1536240
# 		Move Idle at 1536300
# 		Move OLB at 1536480
# 		Move Idle at 1536660
# 		Move JumpingJack at 1536720
# 		Move OLB at 1536780
# 		Move Idle at 1536840
# 		Move OLB at 1536900
# 		Move Idle at 1536960
# 		Move OLB at 1537020
# 		Move Idle at 1537200
# 		Move OLB at 1537560
# 		Move TheShoot at 1537740
# 		Move OLB at 1537800
# 		Move Idle at 1537860
# 		Move OLB at 1537920
# 		Move Idle at 1538640
# 		Move OLB at 1538700
# 		Move Idle at 1538820
# 		Move OLB at 1538880
# 		Move Idle at 1538940
# 		Move OLB at 1539000
# 		Move Idle at 1539600
# 		Move OLB at 1539780
# 		Move Idle at 1540020
# 		Move OLB at 1540380
# 		Move Idle at 1540440
# 		Move TheShoot at 1540500
# 		Move Idle at 1540560
# 		Move OLB at 1540680
# 		Move TheShoot at 1540740
# 		Move OLB at 1540800
# 		Move Idle at 1540980
# 		Move OLB at 1542000
# 		Move Idle at 1542060
# 		Move OLB at 1542300
# 		Move Walk at 1542360
# 		Move Idle at 1542420
# 		Move OLB at 1542480
# 		Move Idle at 1542540
# 		Move OLB at 1542600
# 		Move Idle at 1542780
# 		Move OLB at 1542900
# 		Move Idle at 1542960
# 		Move OLB at 1543020
# 		Move Idle at 1543080
# 		Move OLB at 1543320
# 		Move Idle at 1543380
# 		Move OLB at 1543620
# 		Move Idle at 1543680
# 		Move TheShoot at 1543800
# 		Move TouchingNose at 1543860
# 		Move Idle at 1544220
# 		Move OLB at 1544280
# 		Move Walk at 1544460
# 		Move OLB at 1544520
# 		Move Idle at 1544640
# 		Move OLB at 1544700
# 		Move Walk at 1544760
# 		Move Idle at 1544820
# 		Move OLB at 1544880
# 		Move Idle at 1545000
# 		Move TouchingNose at 1545120
# 		Move TheShoot at 1545300
# 		Move Idle at 1545360
# 		Move OLB at 1545480
# 		Move Idle at 1545780
# 		Move OLB at 1545840
# 		Move TheShoot at 1545900
# 		Move TouchingNose at 1545960
# 		Move Idle at 1546080
# 		Move Idle at 1546499
# 	Sessions 5
# 		Move JumpingJack at 1680000
# 		Move Idle at 1680120
# 		Move TheShoot at 1681440
# 		Move Idle at 1681500
# 		Move TheShoot at 1683060
# 		Move JumpingJack at 1683120
# 		Move Idle at 1683240
# 		Move OLB at 1683300
# 		Move Idle at 1683360
# 		Move OLB at 1683480
# 		Move Idle at 1683540
# 		Move TheShoot at 1683600
# 		Move JumpingJack at 1683660
# 		Move Idle at 1683720
# 		Move TheShoot at 1684980
# 		Move Walk at 1685040
# 		Move OLB at 1685160
# 		Move Idle at 1685220
# 		Move OLB at 1685280
# 		Move Idle at 1685340
# 		Move TheShoot at 1685880
# 		Move Idle at 1685940
# 		Move JumpingJack at 1686600
# 		Move Idle at 1686660
# 		Move TheShoot at 1687260
# 		Move Idle at 1687380
# 		Move TheShoot at 1687440
# 		Move Idle at 1687500
# 		Move JumpingJack at 1687560
# 		Move TheShoot at 1687620
# 		Move JumpingJack at 1687680
# 		Move Idle at 1687800
# 		Move TheShoot at 1687860
# 		Move Idle at 1688040
# 		Move OLB at 1688280
# 		Move Idle at 1688340
# 		Move TheShoot at 1689480
# 		Move Idle at 1689660
# 		Move TheShoot at 1689720
# 		Move OLB at 1689780
# 		Move TheShoot at 1689840
# 		Move OLB at 1689900
# 		Move TheShoot at 1689960
# 		Move Idle at 1690020
# 		Move OLB at 1690920
# 		Move Idle at 1691040
# 		Move TheShoot at 1691100
# 		Move Idle at 1691160
# 		Move TheShoot at 1691220
# 		Move Idle at 1691280
# 		Move OLB at 1691520
# 		Move Walk at 1691580
# 		Move Idle at 1691640
# 		Move Walk at 1691940
# 		Move Idle at 1692000
# 		Move OLB at 1692480
# 		Move Idle at 1692540
# 		Move OLB at 1692600
# 		Move Idle at 1692720
# 		Move OLB at 1692780
# 		Move TheShoot at 1692840
# 		Move Idle at 1692960
# 		Move TheShoot at 1693080
# 		Move Idle at 1693140
# 		Move TheShoot at 1693560
# 		Move Idle at 1693680
# 		Move OLB at 1693740
# 		Move Idle at 1693800
# 		Move TheShoot at 1693980
# 		Move Idle at 1694040
# 		Move TheShoot at 1694460
# 		Move Idle at 1694640
# 		Move TheShoot at 1694820
# 		Move OLB at 1694880
# 		Move Walk at 1695060
# 		Move Idle at 1695120
# 		Move TheShoot at 1695420
# 		Move Idle at 1695660
# 		Move JumpingJack at 1695720
# 		Move Idle at 1695780
# 		Move TheShoot at 1695840
# 		Move OLB at 1695960
# 		Move Walk at 1696020
# 		Move TheShoot at 1696080
# 		Move Idle at 1696140
# 		Move Walk at 1696320
# 		Move Idle at 1696500
# 		Move OLB at 1696560
# 		Move Idle at 1696680
# 		Move Walk at 1696740
# 		Move Idle at 1696800
# 		Move OLB at 1697100
# 		Move Idle at 1697160
# 		Move Walk at 1697340
# 		Move Idle at 1697400
# 		Move OLB at 1697520
# 		Move Idle at 1697640
# 		Move TheShoot at 1697760
# 		Move OLB at 1697820
# 		Move Idle at 1697940
# 		Move JumpingJack at 1698180
# 		Move TheShoot at 1698300
# 		Move Idle at 1698360
# 		Move OLB at 1698780
# 		Move Idle at 1698840
# 		Move OLB at 1699680
# 		Move Idle at 1699740
# 		Move TouchingNose at 1699860
# 		Move JumpingJack at 1700220
# 		Move Idle at 1700280
# 		Move Walk at 1700760
# 		Move Idle at 1700820
# 		Move OLB at 1700880
# 		Move Idle at 1700940
# 		Move TouchingNose at 1701180
# 		Move Idle at 1701360
# 		Move TheShoot at 1701540
# 		Move Idle at 1701600
# 		Move Idle at 1701659
# 	Sessions 6
# 		Move Idle at 1714919
# User PFL004
# 	Sessions 1
# 		Move OLB at 46320
# 		Move Idle at 46440
# 		Move TheShoot at 46740
# 		Move Idle at 46860
# 		Move OLB at 46920
# 		Move Idle at 46980
# 		Move OLB at 47220
# 		Move Idle at 47280
# 		Move JumpingJack at 47760
# 		Move Idle at 47820
# 		Move JumpingJack at 47880
# 		Move TheShoot at 47940
# 		Move OLB at 48000
# 		Move Idle at 48060
# 		Move JumpingJack at 48420
# 		Move Idle at 48900
# 		Move OLB at 49140
# 		Move Idle at 49620
# 		Move OLB at 49860
# 		Move Idle at 51000
# 		Move JumpLeft at 51060
# 		Move Walk at 51120
# 		Move OLB at 51180
# 		Move Walk at 51300
# 		Move JumpRight at 51360
# 		Move Walk at 51420
# 		Move OLB at 51480
# 		Move Idle at 52140
# 		Move Walk at 52320
# 		Move Idle at 52380
# 		Move OLB at 52500
# 		Move TheShoot at 52560
# 		Move OLB at 52620
# 		Move TheShoot at 52740
# 		Move OLB at 52800
# 		Move Walk at 52860
# 		Move JumpLeft at 52920
# 		Move TheShoot at 52980
# 		Move Idle at 53220
# 		Move TheShoot at 60420
# 		Move Idle at 60540
# 		Move TouchingNose at 60840
# 		Move Idle at 60960
# 		Move JumpingJack at 61020
# 		Move Idle at 61080
# 		Move TouchingNose at 61320
# 		Move JumpingJack at 61500
# 		Move Idle at 61560
# 		Move JumpingJack at 61800
# 		Move TouchingNose at 61860
# 		Move Idle at 62040
# 		Move TouchingNose at 62460
# 		Move Idle at 62580
# 		Move OLB at 62940
# 		Move Idle at 63060
# 		Move OLB at 63240
# 		Move Idle at 63540
# 		Move OLB at 63840
# 		Move Idle at 63900
# 		Move OLB at 63960
# 		Move Idle at 64380
# 		Move OLB at 64980
# 		Move Idle at 65040
# 		Move Walk at 65100
# 		Move OLB at 65220
# 		Move Idle at 65280
# 		Move TheShoot at 65700
# 		Move Idle at 65760
# 		Move JumpingJack at 66480
# 		Move Idle at 66540
# 		Move OLB at 66600
# 		Move Idle at 66660
# 		Move JumpingJack at 67080
# 		Move Idle at 67260
# 		Move JumpForward at 67980
# 		Move Idle at 68040
# 		Move Walk at 68100
# 		Move Idle at 68160
# 		Move OLB at 68760
# 		Move Idle at 68820
# 		Move OLB at 69600
# 		Move Walk at 69660
# 		Move JumpForward at 69720
# 		Move Walk at 69780
# 		Move Idle at 69840
# 		Move Walk at 70200
# 		Move TheShoot at 70260
# 		Move Walk at 70320
# 		Move Idle at 70380
# 		Move TheShoot at 70560
# 		Move Walk at 70620
# 		Move Idle at 70680
# 		Move Walk at 72060
# 		Move Idle at 72120
# 		Move OLB at 72180
# 		Move Idle at 72240
# 		Move OLB at 72300
# 		Move Idle at 72360
# 		Move TouchingNose at 73380
# 		Move Idle at 73800
# 		Move JumpLeft at 74460
# 		Move Idle at 74520
# 		Move JumpRight at 74580
# 		Move Idle at 74640
# 		Move TouchingNose at 74700
# 		Move Idle at 74940
# 		Move TheShoot at 75180
# 		Move Idle at 75240
# 		Move TouchingNose at 75480
# 		Move JumpingJack at 75660
# 		Move Idle at 75720
# 		Move Idle at 77159
# 	Sessions 2
# 		Move Idle at 114239
# 	Sessions 3
# 		Move Idle at 232019
# 	Sessions 4
# 		Move Idle at 353939
# 	Sessions 5
# 		Move Idle at 511979
# 	Sessions 6
# 		Move Idle at 857939
# User PFL005
# 	Sessions 1
# 		Move TheShoot at 368760
# 		Move Idle at 369360
# 		Move JumpRight at 369600
# 		Move Idle at 369720
# 		Move TheShoot at 370320
# 		Move TheShoot at 370859
# 	Sessions 2
# 		Move OLB at 375240
# 		Move Idle at 375300
# 		Move JumpingJack at 375360
# 		Move TheShoot at 375540
# 		Move OLB at 375600
# 		Move Idle at 375660
# 		Move TheShoot at 375720
# 		Move JumpLeft at 375840
# 		Move TheShoot at 375900
# 		Move JumpRight at 375960
# 		Move OLB at 376020
# 		Move TheShoot at 376080
# 		Move Walk at 376200
# 		Move TouchingNose at 376260
# 		Move OLB at 376320
# 		Move Idle at 376380
# 		Move TheShoot at 376680
# 		Move Idle at 376740
# 		Move OLB at 376800
# 		Move Idle at 376920
# 		Move OLB at 376980
# 		Move Idle at 377040
# 		Move JumpingJack at 377280
# 		Move TheShoot at 377340
# 		Move JumpingJack at 377400
# 		Move Idle at 377520
# 		Move JumpingJack at 377580
# 		Move Idle at 377640
# 		Move JumpingJack at 377760
# 		Move TheShoot at 378000
# 		Move JumpingJack at 378060
# 		Move TheShoot at 378180
# 		Move JumpingJack at 378300
# 		Move TheShoot at 378360
# 		Move Idle at 378480
# 		Move TheShoot at 378540
# 		Move JumpRight at 378600
# 		Move OLB at 378660
# 		Move TheShoot at 378720
# 		Move JumpingJack at 379260
# 		Move TheShoot at 379320
# 		Move OLB at 379380
# 		Move Idle at 379620
# 		Move TheShoot at 379680
# 		Move JumpingJack at 379740
# 		Move Idle at 379800
# 		Move JumpRight at 379860
# 		Move OLB at 379920
# 		Move Idle at 380040
# 		Move OLB at 380100
# 		Move Idle at 380220
# 		Move Walk at 380280
# 		Move OLB at 380400
# 		Move Walk at 380640
# 		Move Idle at 380700
# 		Move OLB at 380760
# 		Move Idle at 380820
# 		Move OLB at 380880
# 		Move TheShoot at 381000
# 		Move OLB at 381240
# 		Move Walk at 381300
# 		Move Idle at 381360
# 		Move JumpForward at 381420
# 		Move TheShoot at 381480
# 		Move Idle at 381540
# 		Move JumpRight at 381600
# 		Move Walk at 381660
# 		Move Idle at 381720
# 		Move Walk at 381780
# 		Move Idle at 381840
# 		Move TheShoot at 382200
# 		Move Idle at 382260
# 		Move TheShoot at 382320
# 		Move JumpingJack at 382500
# 		Move JumpBack at 382560
# 		Move TheShoot at 382620
# 		Move Idle at 382920
# 		Move OLB at 382980
# 		Move TheShoot at 383040
# 		Move Idle at 383160
# 		Move OLB at 389820
# 		Move Idle at 389880
# 		Move TheShoot at 390120
# 		Move TouchingNose at 390180
# 		Move Idle at 390360
# 		Move OLB at 390420
# 		Move TheShoot at 390480
# 		Move TouchingNose at 390540
# 		Move TheShoot at 390660
# 		Move Idle at 390720
# 		Move TouchingNose at 390780
# 		Move TheShoot at 390900
# 		Move Idle at 390960
# 		Move TheShoot at 391080
# 		Move JumpingJack at 391200
# 		Move Idle at 391260
# 		Move TouchingNose at 391440
# 		Move TheShoot at 391620
# 		Move TouchingNose at 391740
# 		Move TheShoot at 391920
# 		Move Idle at 391980
# 		Move TouchingNose at 392040
# 		Move JumpingJack at 392100
# 		Move TheShoot at 392160
# 		Move Idle at 392220
# 		Move OLB at 392460
# 		Move TheShoot at 392580
# 		Move Idle at 392640
# 		Move OLB at 392820
# 		Move TheShoot at 392940
# 		Move Idle at 393060
# 		Move OLB at 393120
# 		Move TheShoot at 393180
# 		Move OLB at 393240
# 		Move Idle at 393300
# 		Move TheShoot at 393420
# 		Move Idle at 393480
# 		Move OLB at 393600
# 		Move Idle at 393660
# 		Move OLB at 393780
# 		Move TheShoot at 393900
# 		Move JumpingJack at 394020
# 		Move TheShoot at 394080
# 		Move Idle at 394140
# 		Move JumpLeft at 394200
# 		Move JumpBack at 394260
# 		Move TheShoot at 394320
# 		Move Idle at 394380
# 		Move TheShoot at 394560
# 		Move Idle at 394620
# 		Move TheShoot at 394680
# 		Move OLB at 394860
# 		Move JumpingJack at 394920
# 		Move Idle at 394980
# 		Move TheShoot at 395220
# 		Move OLB at 395280
# 		Move TheShoot at 395340
# 		Move Idle at 395400
# 		Move JumpingJack at 395520
# 		Move TheShoot at 395580
# 		Move JumpForward at 395700
# 		Move OLB at 395760
# 		Move TheShoot at 395820
# 		Move Walk at 395880
# 		Move TheShoot at 395940
# 		Move OLB at 396060
# 		Move Idle at 396120
# 		Move TheShoot at 396180
# 		Move Idle at 396300
# 		Move TheShoot at 396540
# 		Move Idle at 396600
# 		Move OLB at 396720
# 		Move TheShoot at 396840
# 		Move OLB at 397020
# 		Move JumpRight at 397200
# 		Move JumpLeft at 397260
# 		Move Idle at 397380
# 		Move OLB at 397440
# 		Move JumpLeft at 397560
# 		Move Walk at 397620
# 		Move JumpForward at 397680
# 		Move TheShoot at 397740
# 		Move Walk at 397800
# 		Move Idle at 397920
# 		Move JumpingJack at 397980
# 		Move JumpLeft at 398040
# 		Move Idle at 398100
# 		Move TheShoot at 398160
# 		Move Walk at 398220
# 		Move JumpForward at 398280
# 		Move Walk at 398340
# 		Move TheShoot at 398400
# 		Move OLB at 398460
# 		Move TheShoot at 398520
# 		Move Idle at 398580
# 		Move Walk at 398640
# 		Move JumpForward at 398700
# 		Move TheShoot at 398760
# 		Move Idle at 398880
# 		Move JumpRight at 399060
# 		Move Idle at 399120
# 		Move JumpForward at 399180
# 		Move TheShoot at 399240
# 		Move JumpLeft at 399480
# 		Move TheShoot at 399540
# 		Move JumpRight at 399600
# 		Move TheShoot at 399660
# 		Move Idle at 399720
# 		Move JumpLeft at 399780
# 		Move Walk at 399840
# 		Move TheShoot at 399900
# 		Move Walk at 399960
# 		Move TheShoot at 400020
# 		Move JumpForward at 400320
# 		Move OLB at 400380
# 		Move Walk at 400440
# 		Move JumpRight at 400500
# 		Move Walk at 400560
# 		Move TheShoot at 400620
# 		Move OLB at 400920
# 		Move Idle at 400980
# 		Move TheShoot at 401040
# 		Move Walk at 401100
# 		Move TheShoot at 401160
# 		Move Idle at 401220
# 		Move Idle at 401279
# 	Sessions 3
# 		Move TheShoot at 604140
# 		Move OLB at 604320
# 		Move Idle at 604380
# 		Move OLB at 604440
# 		Move Idle at 604500
# 		Move OLB at 604860
# 		Move Idle at 604920
# 		Move TheShoot at 605160
# 		Move Idle at 605220
# 		Move OLB at 605280
# 		Move TheShoot at 605340
# 		Move Idle at 605580
# 		Move Walk at 605700
# 		Move TheShoot at 605820
# 		Move TouchingNose at 606180
# 		Move JumpingJack at 606240
# 		Move TheShoot at 606360
# 		Move TouchingNose at 606900
# 		Move JumpForward at 606960
# 		Move TheShoot at 607020
# 		Move TouchingNose at 607080
# 		Move TheShoot at 607200
# 		Move JumpingJack at 607380
# 		Move TheShoot at 607440
# 		Move Idle at 607560
# 		Move JumpLeft at 607680
# 		Move TheShoot at 607740
# 		Move Idle at 607800
# 		Move JumpRight at 607860
# 		Move Walk at 607920
# 		Move TheShoot at 607980
# 		Move OLB at 608040
# 		Move TheShoot at 608100
# 		Move TouchingNose at 608160
# 		Move TheShoot at 608220
# 		Move OLB at 608400
# 		Move Idle at 608460
# 		Move JumpRight at 608520
# 		Move TheShoot at 608580
# 		Move JumpingJack at 608700
# 		Move Idle at 608760
# 		Move TheShoot at 609060
# 		Move JumpForward at 609240
# 		Move Walk at 609300
# 		Move TheShoot at 609360
# 		Move OLB at 609420
# 		Move TheShoot at 609480
# 		Move Idle at 609540
# 		Move TheShoot at 609600
# 		Move Walk at 609720
# 		Move TheShoot at 609780
# 		Move Walk at 609840
# 		Move Idle at 609900
# 		Move TheShoot at 609960
# 		Move OLB at 610260
# 		Move JumpForward at 610320
# 		Move Walk at 610440
# 		Move TheShoot at 610500
# 		Move Walk at 610560
# 		Move TheShoot at 610620
# 		Move TouchingNose at 610740
# 		Move OLB at 610800
# 		Move TheShoot at 610860
# 		Move TouchingNose at 611340
# 		Move TheShoot at 611400
# 		Move TouchingNose at 611460
# 		Move TheShoot at 611700
# 		Move TouchingNose at 611880
# 		Move TheShoot at 612000
# 		Move JumpBack at 612480
# 		Move TheShoot at 612540
# 		Move TouchingNose at 612720
# 		Move TheShoot at 612900
# 		Move TouchingNose at 612960
# 		Move TheShoot at 613080
# 		Move Walk at 613200
# 		Move TheShoot at 613260
# 		Move JumpingJack at 613380
# 		Move TouchingNose at 613680
# 		Move JumpingJack at 613740
# 		Move TheShoot at 613800
# 		Move Walk at 613860
# 		Move JumpRight at 613920
# 		Move Idle at 613980
# 		Move JumpRight at 614160
# 		Move Idle at 614220
# 		Move OLB at 614280
# 		Move Idle at 614340
# 		Move TheShoot at 614460
# 		Move OLB at 614640
# 		Move Idle at 614700
# 		Move TheShoot at 614820
# 		Move Idle at 614880
# 		Move OLB at 615000
# 		Move Idle at 615060
# 		Move OLB at 615120
# 		Move Idle at 615300
# 		Move JumpLeft at 615780
# 		Move Idle at 615840
# 		Move TheShoot at 616080
# 		Move Walk at 616140
# 		Move TheShoot at 616200
# 		Move Walk at 616320
# 		Move TheShoot at 616380
# 		Move OLB at 616500
# 		Move TheShoot at 616560
# 		Move TouchingNose at 616620
# 		Move JumpingJack at 616740
# 		Move TheShoot at 616800
# 		Move TouchingNose at 617100
# 		Move Walk at 617280
# 		Move Idle at 617400
# 		Move TheShoot at 617520
# 		Move JumpRight at 617640
# 		Move Idle at 617700
# 		Move TheShoot at 617760
# 		Move JumpingJack at 617820
# 		Move TheShoot at 617880
# 		Move TouchingNose at 617940
# 		Move Idle at 618120
# 		Move OLB at 618180
# 		Move Idle at 618240
# 		Move JumpRight at 618300
# 		Move OLB at 618360
# 		Move Idle at 618420
# 		Move OLB at 618540
# 		Move TheShoot at 618600
# 		Move OLB at 618840
# 		Move TheShoot at 618900
# 		Move OLB at 619020
# 		Move Walk at 619080
# 		Move TheShoot at 619140
# 		Move OLB at 619260
# 		Move TheShoot at 619320
# 		Move Walk at 619680
# 		Move TheShoot at 619740
# 		Move JumpBack at 619800
# 		Move JumpRight at 619860
# 		Move Idle at 619920
# 		Move Walk at 620220
# 		Move Idle at 620280
# 		Move Walk at 620460
# 		Move TheShoot at 620520
# 		Move Walk at 620640
# 		Move TheShoot at 620760
# 		Move Walk at 620880
# 		Move TheShoot at 621180
# 		Move Walk at 621240
# 		Move Idle at 621360
# 		Move JumpRight at 621420
# 		Move Walk at 621480
# 		Move TheShoot at 621840
# 		Move OLB at 621900
# 		Move TouchingNose at 621960
# 		Move TheShoot at 622020
# 		Move JumpLeft at 622140
# 		Move Idle at 622200
# 		Move JumpBack at 622320
# 		Move TheShoot at 622380
# 		Move TouchingNose at 622680
# 		Move OLB at 622800
# 		Move TheShoot at 622860
# 		Move Walk at 623460
# 		Move OLB at 623520
# 		Move Idle at 623640
# 		Move OLB at 623820
# 		Move TheShoot at 623880
# 		Move Walk at 623940
# 		Move Idle at 624000
# 		Move Walk at 624060
# 		Move TheShoot at 624120
# 		Move Walk at 624240
# 		Move OLB at 624300
# 		Move TheShoot at 624360
# 		Move JumpRight at 624600
# 		Move JumpingJack at 624660
# 		Move TheShoot at 624720
# 		Move JumpingJack at 624780
# 		Move TheShoot at 624840
# 		Move OLB at 624900
# 		Move Idle at 625140
# 		Move Idle at 636959
# 	Sessions 4
# 		Move TheShoot at 791580
# 		Move Idle at 791640
# 		Move TheShoot at 791700
# 		Move JumpBack at 791940
# 		Move OLB at 792000
# 		Move TheShoot at 792120
# 		Move Idle at 792360
# 		Move OLB at 792420
# 		Move Idle at 792480
# 		Move JumpRight at 792540
# 		Move TheShoot at 792600
# 		Move Idle at 792660
# 		Move TheShoot at 792720
# 		Move JumpingJack at 792960
# 		Move TheShoot at 793020
# 		Move JumpingJack at 793080
# 		Move Idle at 793140
# 		Move OLB at 793440
# 		Move JumpLeft at 793500
# 		Move OLB at 793560
# 		Move Idle at 793620
# 		Move OLB at 793800
# 		Move JumpForward at 793860
# 		Move TheShoot at 793920
# 		Move TouchingNose at 794040
# 		Move TheShoot at 794100
# 		Move Idle at 794160
# 		Move TheShoot at 794400
# 		Move JumpingJack at 794460
# 		Move TouchingNose at 794520
# 		Move JumpingJack at 794580
# 		Move TheShoot at 794640
# 		Move OLB at 794700
# 		Move TheShoot at 794760
# 		Move Idle at 794820
# 		Move JumpRight at 794880
# 		Move TheShoot at 794940
# 		Move JumpingJack at 795240
# 		Move TheShoot at 795300
# 		Move JumpingJack at 795420
# 		Move TheShoot at 795480
# 		Move Idle at 795540
# 		Move TheShoot at 795600
# 		Move JumpingJack at 795720
# 		Move TheShoot at 795780
# 		Move JumpingJack at 795900
# 		Move TheShoot at 795960
# 		Move JumpingJack at 796020
# 		Move TheShoot at 796080
# 		Move JumpForward at 796320
# 		Move JumpLeft at 796560
# 		Move JumpForward at 796620
# 		Move JumpLeft at 796680
# 		Move TheShoot at 796740
# 		Move JumpingJack at 796860
# 		Move TouchingNose at 796920
# 		Move TheShoot at 796980
# 		Move TouchingNose at 797040
# 		Move TheShoot at 797100
# 		Move OLB at 797160
# 		Move TheShoot at 797220
# 		Move TouchingNose at 797400
# 		Move TheShoot at 797460
# 		Move OLB at 797520
# 		Move Idle at 797580
# 		Move JumpingJack at 797640
# 		Move TheShoot at 798000
# 		Move Idle at 798120
# 		Move OLB at 798240
# 		Move Idle at 798420
# 		Move OLB at 798600
# 		Move Idle at 798660
# 		Move OLB at 798780
# 		Move JumpForward at 798840
# 		Move TheShoot at 798900
# 		Move OLB at 799020
# 		Move TheShoot at 799080
# 		Move OLB at 799140
# 		Move Idle at 799260
# 		Move OLB at 799320
# 		Move Idle at 799380
# 		Move OLB at 799440
# 		Move Idle at 799560
# 		Move OLB at 799620
# 		Move Idle at 799860
# 		Move Walk at 799920
# 		Move OLB at 799980
# 		Move Idle at 800040
# 		Move OLB at 800100
# 		Move TheShoot at 800160
# 		Move Walk at 800340
# 		Move JumpRight at 800400
# 		Move JumpingJack at 800460
# 		Move TheShoot at 800520
# 		Move JumpBack at 800580
# 		Move JumpForward at 800640
# 		Move Walk at 800700
# 		Move TheShoot at 800820
# 		Move JumpingJack at 800880
# 		Move TheShoot at 800940
# 		Move Idle at 801000
# 		Move OLB at 801060
# 		Move Idle at 801120
# 		Move OLB at 801240
# 		Move TheShoot at 801420
# 		Move OLB at 801480
# 		Move Idle at 801780
# 		Move OLB at 801840
# 		Move Walk at 801900
# 		Move TheShoot at 801960
# 		Move OLB at 802020
# 		Move TheShoot at 802080
# 		Move Walk at 802140
# 		Move TheShoot at 802200
# 		Move JumpForward at 802260
# 		Move OLB at 802320
# 		Move JumpForward at 802380
# 		Move Idle at 802440
# 		Move Idle at 824279
# 	Sessions 5
# 		Move Idle at 1480019
# 	Sessions 6
# 		Move Idle at 1480139
# User PFL006
# 	Sessions 1
# 		Move Idle at 1109520
# 		Move TheShoot at 1109640
# 		Move Idle at 1109760
# 		Move OLB at 1109820
# 		Move Idle at 1110120
# 		Move TheShoot at 1110180
# 		Move OLB at 1110360
# 		Move Idle at 1110420
# 		Move OLB at 1110480
# 		Move TheShoot at 1110600
# 		Move Idle at 1110660
# 		Move OLB at 1110720
# 		Move Idle at 1110780
# 		Move OLB at 1110900
# 		Move TheShoot at 1110960
# 		Move Idle at 1111020
# 		Move TheShoot at 1111080
# 		Move Walk at 1111140
# 		Move TheShoot at 1111200
# 		Move Idle at 1111260
# 		Move OLB at 1111320
# 		Move Idle at 1111380
# 		Move TheShoot at 1111440
# 		Move Idle at 1111560
# 		Move OLB at 1111620
# 		Move Idle at 1111680
# 		Move TheShoot at 1111740
# 		Move OLB at 1111800
# 		Move Idle at 1112040
# 		Move OLB at 1112100
# 		Move Idle at 1112160
# 		Move OLB at 1112220
# 		Move Idle at 1112820
# 		Move Walk at 1112880
# 		Move Idle at 1112940
# 		Move OLB at 1113000
# 		Move Idle at 1113060
# 		Move OLB at 1113120
# 		Move Idle at 1113600
# 		Move OLB at 1113720
# 		Move JumpingJack at 1113840
# 		Move Idle at 1113900
# 		Move OLB at 1113960
# 		Move Idle at 1114020
# 		Move OLB at 1114080
# 		Move Idle at 1114200
# 		Move TheShoot at 1114380
# 		Move JumpingJack at 1114560
# 		Move OLB at 1114860
# 		Move TheShoot at 1114980
# 		Move Idle at 1115040
# 		Move OLB at 1115160
# 		Move Idle at 1115280
# 		Move TheShoot at 1115340
# 		Move OLB at 1115400
# 		Move Idle at 1115580
# 		Move OLB at 1115640
# 		Move Idle at 1115700
# 		Move OLB at 1115760
# 		Move Idle at 1115940
# 		Move OLB at 1116000
# 		Move Idle at 1116300
# 		Move OLB at 1116360
# 		Move Idle at 1116420
# 		Move OLB at 1116540
# 		Move Idle at 1116600
# 		Move OLB at 1116720
# 		Move Idle at 1116900
# 		Move TheShoot at 1116960
# 		Move OLB at 1117020
# 		Move TheShoot at 1117080
# 		Move OLB at 1117140
# 		Move TheShoot at 1117260
# 		Move Idle at 1117320
# 		Move OLB at 1117500
# 		Move Idle at 1117680
# 		Move TheShoot at 1117740
# 		Move OLB at 1117800
# 		Move TheShoot at 1118280
# 		Move Idle at 1118400
# 		Move OLB at 1118700
# 		Move TheShoot at 1118940
# 		Move OLB at 1119060
# 		Move Idle at 1119120
# 		Move OLB at 1119180
# 		Move TheShoot at 1119240
# 		Move Idle at 1119420
# 		Move OLB at 1128000
# 		Move TheShoot at 1128120
# 		Move Idle at 1128180
# 		Move OLB at 1128540
# 		Move Idle at 1128600
# 		Move OLB at 1128900
# 		Move JumpingJack at 1128960
# 		Move TheShoot at 1129020
# 		Move JumpingJack at 1129080
# 		Move Idle at 1129140
# 		Move TouchingNose at 1129440
# 		Move Idle at 1129620
# 		Move OLB at 1130040
# 		Move Idle at 1130100
# 		Move TouchingNose at 1130160
# 		Move Idle at 1130400
# 		Move JumpingJack at 1130820
# 		Move Idle at 1131060
# 		Move OLB at 1131300
# 		Move JumpingJack at 1131360
# 		Move TheShoot at 1131420
# 		Move Idle at 1131540
# 		Move OLB at 1131660
# 		Move TheShoot at 1131780
# 		Move JumpingJack at 1131840
# 		Move Idle at 1131960
# 		Move OLB at 1132140
# 		Move Idle at 1132200
# 		Move OLB at 1132260
# 		Move JumpingJack at 1132620
# 		Move TheShoot at 1132860
# 		Move Idle at 1133280
# 		Move OLB at 1133340
# 		Move TheShoot at 1133400
# 		Move Idle at 1133460
# 		Move TheShoot at 1133760
# 		Move JumpingJack at 1133820
# 		Move TheShoot at 1133880
# 		Move Walk at 1133940
# 		Move Idle at 1134000
# 		Move TheShoot at 1134060
# 		Move Idle at 1134360
# 		Move JumpingJack at 1134420
# 		Move Idle at 1134480
# 		Move TheShoot at 1134600
# 		Move Idle at 1134720
# 		Move JumpingJack at 1134780
# 		Move Idle at 1134840
# 		Move TheShoot at 1134900
# 		Move JumpingJack at 1134960
# 		Move Idle at 1135020
# 		Move TheShoot at 1135320
# 		Move Idle at 1135500
# 		Move JumpingJack at 1135560
# 		Move Idle at 1135620
# 		Move OLB at 1135680
# 		Move TheShoot at 1135740
# 		Move JumpLeft at 1135860
# 		Move Idle at 1135920
# 		Move TheShoot at 1136040
# 		Move Idle at 1136100
# 		Move JumpingJack at 1136160
# 		Move TheShoot at 1136220
# 		Move JumpingJack at 1136340
# 		Move Walk at 1136400
# 		Move TheShoot at 1136460
# 		Move Idle at 1136520
# 		Move TheShoot at 1136700
# 		Move OLB at 1136760
# 		Move JumpingJack at 1136820
# 		Move Idle at 1136880
# 		Move OLB at 1137000
# 		Move Idle at 1137060
# 		Move OLB at 1137300
# 		Move TheShoot at 1137360
# 		Move JumpRight at 1137480
# 		Move OLB at 1137600
# 		Move Idle at 1137660
# 		Move JumpingJack at 1137720
# 		Move OLB at 1137780
# 		Move TheShoot at 1137840
# 		Move Idle at 1137900
# 		Move OLB at 1138020
# 		Move Idle at 1138080
# 		Move TheShoot at 1138140
# 		Move Walk at 1138260
# 		Move OLB at 1138320
# 		Move JumpingJack at 1138380
# 		Move TheShoot at 1138440
# 		Move Idle at 1138560
# 		Move Walk at 1138620
# 		Move Idle at 1138680
# 		Move TheShoot at 1138740
# 		Move Idle at 1138860
# 		Move OLB at 1138920
# 		Move TheShoot at 1138980
# 		Move Idle at 1139100
# 		Move OLB at 1139220
# 		Move TheShoot at 1139280
# 		Move Idle at 1139340
# 		Move TheShoot at 1139700
# 		Move Idle at 1139760
# 		Move TheShoot at 1139940
# 		Move Idle at 1140000
# 		Move JumpingJack at 1140060
# 		Move TheShoot at 1140180
# 		Move JumpForward at 1140300
# 		Move TheShoot at 1140360
# 		Move Idle at 1140480
# 		Move TheShoot at 1141320
# 		Move TheShoot at 1141379
# 	Sessions 2
# 		Move Idle at 1141859
# 	Sessions 3
# 		Move Idle at 1265399
# 	Sessions 4
# 		Move TheShoot at 1288020
# 		Move Idle at 1288080
# 		Move TheShoot at 1288560
# 		Move Idle at 1288620
# 		Move JumpingJack at 1289340
# 		Move TheShoot at 1289460
# 		Move JumpingJack at 1289520
# 		Move TheShoot at 1289820
# 		Move Idle at 1289940
# 		Move Idle at 1295099
# 	Sessions 5
# 		Move Idle at 2025119
# 	Sessions 6
# 		Move JumpingJack at 2026320
# 		Move TheShoot at 2026380
# 		Move Idle at 2026800
# 		Move JumpingJack at 2027160
# 		Move Idle at 2027220
# 		Move JumpingJack at 2027760
# 		Move TouchingNose at 2027820
# 		Move Idle at 2028180
# 		Move TheShoot at 2028480
# 		Move Idle at 2028540
# 		Move Walk at 2028660
# 		Move TheShoot at 2028720
# 		Move OLB at 2028780
# 		Move Idle at 2028960
# 		Move JumpingJack at 2029080
# 		Move TouchingNose at 2029140
# 		Move Idle at 2029320
# 		Move OLB at 2029440
# 		Move Idle at 2029560
# 		Move TheShoot at 2029740
# 		Move Idle at 2029800
# 		Move JumpingJack at 2029860
# 		Move TouchingNose at 2029920
# 		Move JumpingJack at 2030100
# 		Move Idle at 2030160
# 		Move OLB at 2030880
# 		Move Idle at 2030940
# 		Move TheShoot at 2031180
# 		Move Idle at 2031240
# 		Move OLB at 2031300
# 		Move JumpRight at 2031360
# 		Move TheShoot at 2031420
# 		Move Idle at 2031720
# 		Move TheShoot at 2031840
# 		Move OLB at 2031900
# 		Move Idle at 2031960
# ...
# 		Move Idle at 1071840
# 		Move OLB at 1071900
# 		Move Idle at 1072080
# 		Move OLB at 1072140
# 		Move Idle at 1072260
# 		Move Idle at 1072379
# 	Sessions 2
# 		Move JumpingJack at 1079700
# 		Move Idle at 1079760
# 		Move TheShoot at 1081140
# 		Move TouchingNose at 1081200
# 		Move JumpingJack at 1081500
# 		Move Idle at 1081560
# 		Move Walk at 1081740
# 		Move Idle at 1081800
# 		Move OLB at 1082100
# 		Move Idle at 1082160
# 		Move TouchingNose at 1082460
# 		Move JumpingJack at 1082640
# 		Move Idle at 1082700
# 		Move Walk at 1082820
# 		Move OLB at 1082880
# 		Move Idle at 1082940
# 		Move TouchingNose at 1083240
# 		Move JumpingJack at 1083420
# 		Move Idle at 1083480
# 		Move OLB at 1092360
# 		Move Idle at 1092540
# 		Move OLB at 1092600
# 		Move Idle at 1092660
# 		Move OLB at 1092720
# 		Move Idle at 1092780
# 		Move OLB at 1093440
# 		Move Idle at 1093500
# 		Move JumpingJack at 1093680
# 		Move TouchingNose at 1093740
# 		Move Idle at 1094100
# 		Move JumpingJack at 1094160
# 		Move Walk at 1094220
# 		Move Idle at 1094400
# 		Move OLB at 1094580
# 		Move Walk at 1094640
# 		Move Idle at 1094700
# 		Move OLB at 1094820
# 		Move Idle at 1094880
# 		Move TouchingNose at 1095000
# 		Move JumpingJack at 1095180
# 		Move Idle at 1095240
# 		Move Walk at 1095420
# 		Move Idle at 1095480
# 		Move TouchingNose at 1095780
# 		Move Idle at 1096020
# 		Move JumpingJack at 1096080
# 		Move Idle at 1096140
# 		Move OLB at 1098000
# 		Move Idle at 1098120
# 		Move OLB at 1098240
# 		Move Idle at 1098300
# 		Move JumpingJack at 1098660
# 		Move Idle at 1098780
# 		Move OLB at 1098840
# 		Move Walk at 1098900
# 		Move Idle at 1098960
# 		Move TouchingNose at 1099320
# 		Move JumpingJack at 1099500
# 		Move OLB at 1099560
# 		Move Idle at 1099620
# 		Move JumpingJack at 1099680
# 		Move Idle at 1099800
# 		Move TouchingNose at 1099860
# 		Move JumpingJack at 1100040
# 		Move Idle at 1100100
# 		Move Walk at 1100220
# 		Move Idle at 1100280
# 		Move OLB at 1100340
# 		Move Idle at 1100400
# 		Move OLB at 1100460
# 		Move Idle at 1100520
# 		Move OLB at 1100760
# 		Move Idle at 1100820
# 		Move OLB at 1100880
# 		Move Idle at 1100940
# 		Move TheShoot at 1101060
# 		Move Idle at 1101120
# 		Move TheShoot at 1101180
# 		Move Idle at 1101300
# 		Move JumpingJack at 1101360
# 		Move Idle at 1101480
# 		Move Idle at 1108919
# 	Sessions 3
# 		Move Idle at 1206239
# 	Sessions 4
# 		Move OLB at 1207560
# 		Move Idle at 1207620
# 		Move TheShoot at 1208160
# 		Move OLB at 1208220
# 		Move TheShoot at 1208280
# 		Move Idle at 1208340
# 		Move OLB at 1208400
# 		Move Idle at 1208460
# 		Move TheShoot at 1208580
# 		Move OLB at 1208640
# 		Move Idle at 1208700
# 		Move OLB at 1208760
# 		Move Walk at 1208820
# 		Move Idle at 1208880
# 		Move OLB at 1208940
# 		Move Idle at 1209060
# 		Move TheShoot at 1209240
# 		Move TouchingNose at 1209300
# 		Move TheShoot at 1209420
# 		Move Idle at 1209480
# 		Move OLB at 1209720
# 		Move TouchingNose at 1209780
# 		Move Idle at 1210020
# 		Move OLB at 1210200
# 		Move Idle at 1210440
# 		Move TheShoot at 1210560
# 		Move Idle at 1210620
# 		Move OLB at 1210680
# 		Move Idle at 1210740
# 		Move OLB at 1210860
# 		Move Idle at 1210920
# 		Move OLB at 1211100
# 		Move JumpForward at 1211160
# 		Move JumpingJack at 1211220
# 		Move TheShoot at 1211340
# 		Move Idle at 1211400
# 		Move OLB at 1211640
# 		Move Idle at 1211760
# 		Move OLB at 1212480
# 		Move Idle at 1212540
# 		Move OLB at 1212600
# 		Move Idle at 1212660
# 		Move OLB at 1212780
# 		Move Idle at 1212840
# 		Move OLB at 1212900
# 		Move Idle at 1212960
# 		Move OLB at 1213080
# 		Move Idle at 1213140
# 		Move OLB at 1213260
# 		Move Idle at 1213320
# 		Move OLB at 1213500
# 		Move Walk at 1213560
# 		Move Idle at 1213620
# 		Move TheShoot at 1213920
# 		Move Idle at 1213980
# 		Move OLB at 1214100
# 		Move TheShoot at 1214160
# 		Move OLB at 1214220
# 		Move Idle at 1214400
# 		Move OLB at 1214460
# 		Move Idle at 1214520
# 		Move TheShoot at 1214580
# 		Move TouchingNose at 1214640
# 		Move JumpingJack at 1214760
# 		Move TheShoot at 1214820
# 		Move Idle at 1214880
# 		Move OLB at 1215060
# 		Move JumpingJack at 1215120
# 		Move TouchingNose at 1215180
# 		Move JumpingJack at 1215300
# 		Move OLB at 1215360
# 		Move Idle at 1215780
# 		Move OLB at 1215840
# 		Move Idle at 1215900
# 		Move OLB at 1216020
# 		Move Idle at 1216080
# 		Move TheShoot at 1216140
# 		Move OLB at 1216200
# 		Move Idle at 1216380
# 		Move OLB at 1216440
# 		Move JumpingJack at 1216560
# 		Move Idle at 1216680
# 		Move TheShoot at 1216740
# 		Move Walk at 1216800
# 		Move Idle at 1216860
# 		Move TheShoot at 1228200
# 		Move Idle at 1228260
# 		Move OLB at 1228500
# 		Move Idle at 1228560
# 		Move OLB at 1228800
# 		Move Idle at 1228860
# 		Move OLB at 1228920
# 		Move TheShoot at 1229040
# 		Move OLB at 1229100
# 		Move Walk at 1229160
# 		Move OLB at 1229220
# 		Move Idle at 1229280
# 		Move OLB at 1229520
# 		Move Idle at 1229580
# 		Move JumpingJack at 1229640
# 		Move Walk at 1229760
# 		Move Idle at 1229820
# 		Move Walk at 1229880
# 		Move Idle at 1229940
# 		Move TouchingNose at 1230300
# 		Move JumpingJack at 1230480
# 		Move TheShoot at 1230540
# 		Move Idle at 1230660
# 		Move OLB at 1230780
# 		Move TouchingNose at 1230840
# 		Move Idle at 1231020
# 		Move OLB at 1231080
# 		Move Idle at 1231200
# 		Move TheShoot at 1231320
# 		Move OLB at 1231380
# 		Move Idle at 1231620
# 		Move OLB at 1231680
# 		Move Idle at 1231800
# 		Move OLB at 1231860
# 		Move Idle at 1231920
# 		Move OLB at 1231980
# 		Move TheShoot at 1232100
# 		Move Idle at 1232160
# 		Move TheShoot at 1232220
# 		Move OLB at 1232520
# 		Move Idle at 1232700
# 		Move Idle at 1232759
# 	Sessions 5
# 		Move OLB at 1769520
# 		Move Idle at 1769580
# 		Move OLB at 1770180
# 		Move Idle at 1770240
# 		Move TheShoot at 1770360
# 		Move OLB at 1770420
# 		Move TheShoot at 1770480
# 		Move Idle at 1770540
# 		Move JumpBack at 1770600
# 		Move Idle at 1770660
# 		Move TheShoot at 1770780
# 		Move Idle at 1770900
# 		Move JumpingJack at 1770960
# 		Move Walk at 1771020
# 		Move OLB at 1771080
# 		Move Idle at 1771140
# 		Move OLB at 1771260
# 		Move JumpingJack at 1771500
# 		Move TouchingNose at 1771560
# 		Move TheShoot at 1771740
# 		Move OLB at 1771800
# 		Move Idle at 1771860
# 		Move OLB at 1771920
# 		Move TheShoot at 1772040
# 		Move TouchingNose at 1772100
# 		Move TheShoot at 1772280
# 		Move OLB at 1772340
# 		Move Idle at 1772700
# 		Move OLB at 1772760
# 		Move Idle at 1773060
# 		Move OLB at 1773120
# 		Move Idle at 1773240
# 		Move OLB at 1773300
# 		Move Idle at 1773420
# 		Move JumpingJack at 1773480
# 		Move JumpRight at 1773540
# 		Move Idle at 1773600
# 		Move JumpingJack at 1773660
# 		Move TheShoot at 1773780
# 		Move Idle at 1773840
# 		Move TheShoot at 1774560
# 		Move TouchingNose at 1774620
# 		Move Idle at 1774920
# 		Move OLB at 1774980
# 		Move Idle at 1775040
# 		Move OLB at 1775100
# 		Move Idle at 1775160
# 		Move OLB at 1775280
# 		Move TheShoot at 1775520
# 		Move JumpingJack at 1775580
# 		Move TheShoot at 1775640
# 		Move OLB at 1775700
# 		Move Idle at 1775880
# 		Move OLB at 1776000
# 		Move Idle at 1776060
# 		Move OLB at 1776120
# 		Move Idle at 1776180
# 		Move JumpingJack at 1776240
# 		Move Idle at 1776300
# 		Move OLB at 1776360
# 		Move TheShoot at 1776420
# 		Move Idle at 1776480
# 		Move OLB at 1776600
# 		Move Idle at 1776780
# 		Move TheShoot at 1776840
# 		Move OLB at 1776960
# 		Move Idle at 1777140
# 		Move TheShoot at 1777200
# 		Move OLB at 1777380
# 		Move Idle at 1777440
# 		Move OLB at 1777500
# 		Move JumpingJack at 1777560
# 		Move Idle at 1777740
# 		Move JumpingJack at 1777800
# 		Move Idle at 1778040
# 		Move TheShoot at 1778820
# 		Move Idle at 1778880
# 		Move TheShoot at 1778940
# 		Move TouchingNose at 1779000
# 		Move Idle at 1779300
# 		Move OLB at 1779360
# 		Move Idle at 1779420
# 		Move OLB at 1779540
# 		Move Idle at 1779720
# 		Move OLB at 1779780
# 		Move TheShoot at 1779900
# 		Move Idle at 1779960
# 		Move OLB at 1780020
# 		Move Walk at 1780080
# 		Move Idle at 1780140
# 		Move OLB at 1780320
# 		Move TheShoot at 1780560
# 		Move Idle at 1780620
# 		Move TheShoot at 1780680
# 		Move Idle at 1780740
# 		Move JumpRight at 1780860
# 		Move Idle at 1780920
# 		Move JumpRight at 1780980
# 		Move OLB at 1781040
# 		Move TheShoot at 1781160
# 		Move OLB at 1781280
# 		Move Idle at 1781520
# 		Move JumpingJack at 1781580
# 		Move OLB at 1781640
# 		Move Idle at 1781700
# 		Move OLB at 1781760
# 		Move TheShoot at 1781880
# 		Move Idle at 1782000
# 		Move JumpingJack at 1782060
# 		Move TheShoot at 1782120
# 		Move JumpingJack at 1782180
# 		Move TheShoot at 1782240
# 		Move Idle at 1782300
# 		Move TheShoot at 1782420
# 		Move Idle at 1782480
# 		Move TheShoot at 1793940
# 		Move TouchingNose at 1794000
# 		Move JumpingJack at 1794120
# 		Move TouchingNose at 1794180
# 		Move TheShoot at 1794300
# 		Move OLB at 1794360
# 		Move TheShoot at 1794420
# 		Move Idle at 1794480
# 		Move TheShoot at 1794660
# 		Move OLB at 1794720
# 		Move Idle at 1794780
# 		Move OLB at 1794840
# 		Move Idle at 1794900
# 		Move JumpingJack at 1794960
# 		Move Idle at 1795020
# 		Move OLB at 1795080
# 		Move Idle at 1795140
# 		Move TheShoot at 1795200
# 		Move Idle at 1795260
# 		Move OLB at 1795380
# 		Move Idle at 1795560
# 		Move JumpingJack at 1795620
# 		Move Idle at 1795680
# 		Move TheShoot at 1795740
# 		Move Idle at 1795860
# 		Move OLB at 1796040
# 		Move Idle at 1796100
# 		Move OLB at 1796160
# 		Move JumpingJack at 1796280
# 		Move Idle at 1796340
# 		Move OLB at 1796400
# 		Move Idle at 1796520
# 		Move TheShoot at 1796580
# 		Move JumpingJack at 1796640
# 		Move OLB at 1796700
# 		Move TheShoot at 1796940
# 		Move JumpingJack at 1797060
# 		Move Idle at 1797180
# 		Move JumpingJack at 1797240
# 		Move TheShoot at 1797300
# 		Move Idle at 1797420
# 		Move Idle at 1797659
# 	Sessions 6
# 		Move TheShoot at 2236620
# 		Move TouchingNose at 2236680
# 		Move TheShoot at 2236980
# 		Move Idle at 2237160
# 		Move OLB at 2237400
# 		Move Idle at 2237580
# 		Move JumpingJack at 2237640
# 		Move OLB at 2237700
# 		Move Idle at 2237820
# 		Move OLB at 2237940
# 		Move TheShoot at 2238120
# 		Move JumpingJack at 2238300
# 		Move Idle at 2238360
# 		Move TheShoot at 2238420
# 		Move Idle at 2238540
# 		Move TheShoot at 2238600
# 		Move Idle at 2238660
# 		Move TheShoot at 2238720
# 		Move OLB at 2238780
# 		Move JumpingJack at 2238960
# 		Move TheShoot at 2239020
# 		Move OLB at 2239140
# 		Move Idle at 2239200
# 		Move JumpingJack at 2239260
# 		Move OLB at 2239320
# 		Move TheShoot at 2239380
# 		Move OLB at 2239440
# 		Move Idle at 2239500
# 		Move TheShoot at 2239560
# 		Move OLB at 2239620
# 		Move JumpingJack at 2239680
# 		Move TheShoot at 2239860
# 		Move Idle at 2239920
# 		Move JumpingJack at 2239980
# 		Move Idle at 2240100
# 		Move TouchingNose at 2241420
# 		Move JumpingJack at 2241720
# 		Move Idle at 2241780
# 		Move TheShoot at 2241840
# 		Move Idle at 2241900
# 		Move OLB at 2242020
# 		Move Idle at 2242080
# 		Move OLB at 2242140
# 		Move Idle at 2242200
# 		Move OLB at 2242260
# 		Move Idle at 2242320
# 		Move TheShoot at 2242380
# 		Move Idle at 2242440
# 		Move TheShoot at 2242500
# 		Move JumpRight at 2242560
# 		Move Idle at 2242620
# 		Move TheShoot at 2242680
# 		Move Idle at 2242740
# 		Move OLB at 2242800
# 		Move JumpingJack at 2243040
# 		Move Idle at 2243100
# 		Move OLB at 2243160
# 		Move TheShoot at 2243220
# 		Move Idle at 2243400
# 		Move OLB at 2243460
# 		Move TheShoot at 2243700
# 		Move OLB at 2243940
# 		Move TheShoot at 2244000
# 		Move Idle at 2244060
# 		Move TheShoot at 2244120
# 		Move OLB at 2244180
# 		Move TheShoot at 2244240
# 		Move OLB at 2244300
# 		Move JumpingJack at 2244360
# 		Move TheShoot at 2244600
# 		Move JumpingJack at 2244660
# 		Move Idle at 2244840
# 		Move JumpRight at 2245800
# 		Move Idle at 2245860
# 		Move TheShoot at 2245920
# 		Move Idle at 2245980
# 		Move OLB at 2246040
# 		Move TheShoot at 2246160
# 		Move Idle at 2246220
# 		Move TheShoot at 2246280
# 		Move OLB at 2246340
# 		Move TheShoot at 2246400
# 		Move Idle at 2246520
# 		Move TheShoot at 2246580
# 		Move OLB at 2246640
# 		Move TheShoot at 2246700
# 		Move TouchingNose at 2246760
# 		Move JumpingJack at 2246880
# 		Move TheShoot at 2246940
# 		Move JumpingJack at 2247000
# 		Move TouchingNose at 2247060
# 		Move Idle at 2247180
# 		Move OLB at 2247240
# 		Move Idle at 2247300
# 		Move TheShoot at 2247360
# 		Move OLB at 2247420
# 		Move TheShoot at 2247480
# 		Move OLB at 2247660
# 		Move TheShoot at 2247840
# 		Move OLB at 2247960
# 		Move Idle at 2248020
# 		Move OLB at 2248080
# 		Move JumpBack at 2248200
# 		Move OLB at 2248260
# 		Move TheShoot at 2248320
# 		Move TouchingNose at 2248380
# 		Move JumpingJack at 2248500
# 		Move Idle at 2248560
# 		Move TheShoot at 2248620
# 		Move TouchingNose at 2248680
# 		Move TheShoot at 2248860
# 		Move TouchingNose at 2248920
# 		Move JumpingJack at 2249100
# 		Move TouchingNose at 2249220
# 		Move Idle at 2249400
# 		Move OLB at 2249460
# 		Move Idle at 2249520
# 		Move OLB at 2249580
# 		Move Idle at 2249760
# 		Move OLB at 2249820
# 		Move Idle at 2249880
# 		Move TouchingNose at 2249940
# 		Move OLB at 2250180
# 		Move TheShoot at 2250420
# 		Move Idle at 2250480
# 		Move OLB at 2250540
# 		Move TheShoot at 2250660
# 		Move OLB at 2250720
# 		Move TheShoot at 2250840
# 		Move OLB at 2250960
# 		Move Idle at 2251020
# 		Move JumpBack at 2251080
# 		Move Idle at 2251140
# 		Move TheShoot at 2251260
# 		Move OLB at 2251320
# 		Move Idle at 2251380
# 		Move OLB at 2251560
# 		Move Idle at 2251620
# 		Move JumpingJack at 2251800
# 		Move TheShoot at 2251860
# 		Move OLB at 2251920
# 		Move Idle at 2252100
# 		Move OLB at 2252160
# 		Move TheShoot at 2252280
# 		Move Idle at 2252400
# 		Move Idle at 2261939
# User PFL011
# 	Sessions 1
# 		Move Idle at 1173779
# 	Sessions 2
# 		Move TheShoot at 1177740
# 		Move JumpingJack at 1177860
# 		Move TheShoot at 1177980
# 		Move Idle at 1178220
# 		Move JumpingJack at 1178280
# 		Move TheShoot at 1178340
# 		Move Idle at 1178460
# 		Move TheShoot at 1178520
# 		Move OLB at 1178580
# 		Move TheShoot at 1178700
# 		Move Walk at 1178940
# 		Move JumpingJack at 1179000
# 		Move TheShoot at 1179120
# 		Move JumpingJack at 1179180
# 		Move TheShoot at 1179300
# 		Move Idle at 1179360
# 		Move OLB at 1179420
# 		Move Idle at 1179480
# 		Move TheShoot at 1179540
# 		Move JumpingJack at 1179720
# 		Move Idle at 1179780
# 		Move JumpingJack at 1179960
# 		Move TheShoot at 1180080
# 		Move JumpingJack at 1180140
# 		Move Idle at 1180620
# 		Move OLB at 1180740
# 		Move Idle at 1180800
# 		Move TheShoot at 1180860
# 		Move Idle at 1180920
# 		Move OLB at 1181040
# 		Move Idle at 1181160
# 		Move JumpingJack at 1181220
# 		Move TheShoot at 1181280
# 		Move Idle at 1181340
# 		Move OLB at 1181580
# 		Move Idle at 1181700
# 		Move JumpingJack at 1181760
# 		Move TheShoot at 1181820
# 		Move Idle at 1181880
# 		Move JumpingJack at 1182060
# 		Move JumpRight at 1182240
# 		Move Idle at 1182300
# 		Move JumpingJack at 1182540
# 		Move Idle at 1182660
# 		Move OLB at 1182720
# 		Move Walk at 1182780
# 		Move TheShoot at 1182840
# 		Move JumpingJack at 1182900
# 		Move TheShoot at 1183140
# 		Move JumpingJack at 1183320
# 		Move Idle at 1183380
# 		Move JumpingJack at 1183440
# 		Move TheShoot at 1183560
# 		Move JumpingJack at 1183620
# 		Move Walk at 1183680
# 		Move Idle at 1183740
# 		Move JumpingJack at 1183800
# 		Move TheShoot at 1183860
# 		Move Idle at 1183980
# 		Move JumpingJack at 1184040
# 		Move JumpRight at 1184160
# 		Move TheShoot at 1184220
# 		Move Idle at 1184280
# 		Move JumpingJack at 1184340
# 		Move TheShoot at 1184580
# 		Move JumpingJack at 1184700
# 		Move JumpRight at 1185240
# 		Move JumpingJack at 1185300
# 		Move Idle at 1185360
# 		Move OLB at 1185480
# 		Move Walk at 1185600
# 		Move Idle at 1185660
# 		Move Walk at 1185900
# 		Move Idle at 1185960
# 		Move JumpingJack at 1186200
# 		Move OLB at 1186260
# 		Move Walk at 1186500
# 		Move OLB at 1186560
# 		Move Walk at 1186680
# 		Move TheShoot at 1186800
# 		Move Walk at 1186860
# 		Move Idle at 1186980
# 		Move OLB at 1187040
# 		Move TheShoot at 1187100
# 		Move OLB at 1187220
# 		Move TheShoot at 1187340
# 		Move JumpingJack at 1187400
# 		Move Idle at 1187460
# 		Move OLB at 1187520
# 		Move Idle at 1187580
# 		Move Walk at 1187640
# 		Move TheShoot at 1187700
# 		Move JumpingJack at 1187880
# 		Move TheShoot at 1188060
# 		Move Walk at 1188120
# 		Move OLB at 1188240
# 		Move JumpRight at 1188420
# 		Move Idle at 1188480
# 		Move TheShoot at 1188540
# 		Move Idle at 1188600
# 		Move JumpingJack at 1188660
# 		Move TheShoot at 1188720
# 		Move Idle at 1188780
# 		Move OLB at 1188840
# 		Move TheShoot at 1188900
# 		Move OLB at 1189020
# 		Move Idle at 1189200
# 		Move TheShoot at 1189260
# 		Move Idle at 1189380
# 		Move OLB at 1189440
# 		Move Walk at 1189500
# 		Move Idle at 1189560
# 		Move Walk at 1189620
# 		Move TheShoot at 1189680
# 		Move OLB at 1189920
# 		Move Idle at 1189980
# 		Move Idle at 1199339
# CPU times: user 1min 12s, sys: 15.2 s, total: 1min 27s
# Wall time: 1min 27s

# %% [markdown]
# To see a sample of the moves and their length (in frames), we run the following script:

# %%
# %%time

coordinate_columns = [col_prefix+coord for col_prefix in joint_names for coord in ['_x', '_y', '_z']]
counts_pivot_table_aug = captureddata_df_augmented.groupby(['UserID', 'SessionNumber', 'MovementName'], as_index=False).size().to_frame('count').reset_index()
counts_pivot_table_aug.head(20)
# Out:
# CPU times: user 191 ms, sys: 117 ms, total: 308 ms
# Wall time: 312 ms
#     UserID  SessionNumber         MovementName  count
# 0   PFL001              1         Idle@1549440   2940
# 1   PFL001              1         Idle@1550220    480
# 2   PFL001              1         Idle@1550460     60
# 3   PFL001              1         Idle@1551120    120
# 4   PFL001              1         Idle@1551420    240
# 5   PFL001              1         Idle@1552020     60
# 6   PFL001              1         Idle@1552440    360
# 7   PFL001              1         Idle@1552920    420
# 8   PFL001              1         Idle@1553460     60
# 9   PFL001              1         Idle@1554180    360
# 10  PFL001              1         Idle@1554300     60
# 11  PFL001              1         Idle@1554660     60
# 12  PFL001              1         Idle@1555860   1020
# 13  PFL001              1         Idle@1555980     60
# 14  PFL001              1         Idle@1576439  20040
# 15  PFL001              1     JumpBack@1550880     60
# 16  PFL001              1     JumpBack@1555920     60
# 17  PFL001              1  JumpForward@1554240     60
# 18  PFL001              1  JumpForward@1554360     60
# 19  PFL001              1  JumpForward@1556220     60

# %% [markdown]
# And here's a histogram of the non-`Idle` move lengths:

# %%
allcnts = counts_pivot_table_aug[(~counts_pivot_table_aug.MovementName.str.contains('Idle')) &
                                 (counts_pivot_table_aug.SessionNumber < 6)
                                ]['count'].values
plt.figure(figsize=(18,10))
plt.hist(allcnts, bins=500)
plt.xlabel('length', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.show()

# %% [markdown]
# ## Denoising the Moves
#
# Investigating the individual moves signals (see the blue plot below) we see that there are some high-frequency (HF) components present in the captured data that are physically unrealistic. These are artifacts of the data collection devices and procesdures which are not plausible in the context of human movement and need to be removed from the data. To this end, we use wavelet transforms through calling the `denoise_data` function to remove the HF artifacts of the data. Here is an example of the original signal (blue) and the denoised version (orange):

# %%
yy_orig = captureddata_df_augmented[captureddata_df_augmented.MovementName == 'JumpRight@2333400'].Head_x.values
yy = wbm.denoise_data(yy_orig, haarlevel=2, shrinking_factor=1)

plt.figure(figsize=(18,10))
plt.plot(yy_orig, label='orig')
plt.plot(yy, label='denoised')
plt.xlabel('time', fontsize=18)
plt.ylabel('Head_x', fontsize=18)
plt.legend(fontsize=18)
plt.show()

# %% [markdown]
# ## Computing the Synchrony Measures of Articulated Figure Angles for Various Moves
#
# We now use the data created above to analyze various summary statistics of moves and how they correlate with various demographics information. To do so, we go through the following steps:
#
# 1. For each move, we first use the $(x,y,z)$ coordinates of POIs to calculated various articulated figure angles for each frame. We do this by calling the function `calculate_3d_articulated_figure_angles` and specify the angles using the dictionary `_ARTICULATED_FIGURE_ANGLES_3`: <br/><br/>
# <b> {{ print(str(wbm.predefined_schemas.\_ARTICULATED_FIGURE_ANGLES_3).replace("),", "),<br />").replace('"', '')) }} </b>
# <br/><br/> Each entry in this dictionary is of the form `<angle_name>:(<T>,<U>,<S>,<WD>,<POS>)` where `angle_name` is the given name of the angle, and `T`, `U` and `S` are the names of the POIs which specify this angle as $\angle UTS$ (`<WD>` and `<POS>` are relvant only for 2D articulated figures; see documentation for details).

# %% [markdown]
# 2. Next, we pick two of the angles `angle1` and `angle2` from the above articulated figure angles, denoise them using the procedure described before, and calculated various synchrony measures for them. Specifically, we calculate MARP, CRPSD [Meyns et. al.](https://doi.org/10.1016/j.ridd.2012.03.020) and PLV [Wang et. al.](https://doi.org/10.1109/IEMBS.2006.259673) and save them along with some of the demographics data in `sync_measures` table.

# %%
# %%time

unique_user_ids        = [gg for gg in captureddata_df.UserID.unique() if 'PFL' in gg]
unique_user_ids        = sorted(unique_user_ids)
unique_movement_names  = captureddata_df.MovementName.unique()
unique_session_numbers = captureddata_df.SessionNumber.unique()

bar_colors = {
    'Normal': 'g',
    'Moderate': 'b',
    'Severe': 'r',
}

movement_name  = 'Walk'
max_sessions   = 6
angle1          = 'rshldr_theta'
angle2          = 'lhip_theta'

nrows, ncols = int(len(unique_user_ids)**.5)+1, int(len(unique_user_ids)**.5)
jj = 1

shrinking_factor = 1
sync_measures = pd.DataFrame(columns=['ParticipantID', 'BOT_totalraw_pre', 'BOT_grossraw_pre', 'AGE', 'HEIGHT', 'WEIGHT', 'MARP', 'CRPSD', 'PLV'])

miny, maxy = np.inf, -np.inf
for user_id_idx in range(len(unique_user_ids)):
    user_id = unique_user_ids[user_id_idx]
    if user_id not in participant_demographics.index:
        continue
    
    user_movement_first_session_number = sorted(captureddata_df[(captureddata_df.UserID==user_id) & 
                                                         (captureddata_df_augmented.MovementName.str.contains(movement_name))
                                                        ].SessionNumber.unique())[0]

    user_movement_session_trials = sorted(captureddata_df_augmented[(captureddata_df_augmented.UserID==user_id) &
                                                                    (captureddata_df_augmented.SessionNumber==user_movement_first_session_number) &
                                                                    (captureddata_df_augmented.MovementName.str.contains(movement_name))
                                                                   ].MovementName.unique())
    
    for trial_inx in range(len(user_movement_session_trials)):
        trial = user_movement_session_trials[trial_inx]
        
        session_data = captureddata_df_augmented[captureddata_df_augmented.MovementName == trial]
        if session_data.shape[0] == 0:
            continue
#         session_af_data = wbm.calculate_2d_articulated_figure_angles(session_data, 
#                                                                      angles=wbm.predefined_schemas._ARTICULATED_FIGURE_ANGLES_3,
#                                                                      x_suffix='_x', y_suffix='_y',
#                                                                     ).set_index(session_data.index)
        session_af_data = wbm.calculate_3d_articulated_figure_angles(session_data, 
                                                                     angles=wbm.predefined_schemas._ARTICULATED_FIGURE_ANGLES_3,
                                                                     x_suffix='_x', y_suffix='_y', z_suffix='_z',
                                                                    ).set_index(session_data.index)

        session_data = pd.concat([session_data, session_af_data], axis=1).ffill(axis='rows')
        haarlevel = 2
        denoised_session_data = pd.DataFrame(columns=[angle1, angle2])
        for angle in [angle1, angle2]:
            denoised_session_data.loc[:, angle] = wbm.denoise_data(session_data[angle].values, haarlevel=haarlevel, shrinking_factor=shrinking_factor)
        _, marp, _, crpsd = wbm.calculate_phase_angle_measures(denoised_session_data, (angle1, angle2))
        _, plv, _, _, _, _ = wbm.calculate_phase_locking_value(denoised_session_data, (angle1, angle2))
        
        sync_measures.loc[sync_measures.shape[0]] = [user_id,
                                                     1.*participant_demographics.loc[user_id, 'BOT_totalraw_pre'], 
                                                     1.*participant_demographics.loc[user_id, 'BOT_grossraw_pre'], 
                                                     1.*participant_demographics.loc[user_id, 'AGE'], 
                                                     1.*participant_demographics.loc[user_id, 'HEIGHT'], 
                                                     1.*participant_demographics.loc[user_id, 'WEIGHT'],
                                                     marp, 
                                                     crpsd, 
                                                     plv, 
                                                    ]
sync_measures = sync_measures.set_index('ParticipantID')
# Out:
# CPU times: user 39 s, sys: 359 ms, total: 39.4 s
# Wall time: 39.4 s

# %% [markdown]
# Here is a peak at the resulting table:
#
# {{ display(sync_measures.head()) }}

# %% [markdown]
# 3. Then we look at the correlations of various synchrony measures with the demographics data using `jointplot`s:

# %%
independent_measures = ['BOT_totalraw_pre', 'BOT_grossraw_pre', 'AGE', 'HEIGHT', 'WEIGHT']
independent_measure = 'BOT_totalraw_pre'

for cur_measure in ['MARP', 'CRPSD', 'PLV']:
    plt.figure(figsize=(12,8))

    g = sns.jointplot(x=independent_measure, y=cur_measure, data=sync_measures, kind='reg', height=8) #, hue="marker_color", col="marker_color", fit_reg=True)
    g.annotate(stats.pearsonr, fontsize=18)
    g.set_axis_labels(independent_measure, cur_measure, fontsize=24)
#     g.tick_params(labelsize=18)

    plt.show()
# Out:
# /Users/adelardalan/anaconda3/envs/sklearn022/lib/python3.7/site-packages/seaborn/axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
